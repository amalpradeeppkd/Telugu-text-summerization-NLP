# %% [markdown]
# TOPIC : Text Summarization
#
# Corpus Language : Telugu
#
# No.of Team Members : 4

# %% [markdown]
# ![Screenshot 2022-03-14 at 11.30.19 PM.png](data:image/png;base64,...)

# %%
import nltk
from nltk.corpus import stopwords 
import string
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Indic NLP Library

# %%
pip install indic-nlp-library
# Out:
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.7/dist-packages (0.81)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.7/dist-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.7/dist-packages (from indic-nlp-library) (1.0.0)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.7/dist-packages (from indic-nlp-library) (0.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from indic-nlp-library) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from indic-nlp-library) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->indic-nlp-library) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->indic-nlp-library) (1.15.0)
# Requirement already satisfied: sphinx>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx-argparse->indic-nlp-library) (1.8.6)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.11.3)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.9.1)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.23.0)
# Requirement already satisfied: docutils<0.18,>=0.11 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.17.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.6.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (57.4.0)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.2.4)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.12)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.24.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.0.7)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.7/dist-packages (from sphinxcontrib-websupport->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.5)

# %% [markdown]
# # making all corpus into one file

# %%
with open('/content/cse1.txt') as fp:
	data = fp.read()

with open('/content/cse2.txt') as fp:
	data2 = fp.read()

with open('/content/cse3.txt') as fp:
	data3 = fp.read()
 
with open('/content/cse4.txt') as fp:
	data4 = fp.read()


data += "\n"
data += data2
data += "\n"
data += data3
data += "\n"
data += data4
telugu_data = data 
print(telugu_data)
print(len(telugu_data))
# Out:
# అనగనగా ఒక రహదారిలో రాము, గిరి అనబడే ఇద్దరు బాటసారులు కలిసి ప్రయాణం చేస్తున్నారు.దారిలో అనుకోకుండా గిరికి ఒక సంచి కనిపించింది. ఆ సంచి తెరిచి చూస్తే అందులో బంగారు నాణాలు ఉన్నాయి!“నేను యెంత అదృష్టవంతుడిని, నాకు అనుకోకుండా ఇంత బంగారం దొరికింది!” అని గిరి రాముతో అన్నాడు.“నేను అదృష్టవంతుదిని అనకు, మనం అదృష్టవంతులము” అని రాము బదులు చెప్పాడు.“అదెలా కుదురుతుంది? సంచి నాకు దొరికింది కనుక బంగారమూ నాడదే, అదృష్టము నాదే! మనం కాదు; నేను అదృష్టవంతుడిని! అని గిరి కోపంగా అన్నాడు.రాము గొడవ పడడం ఎందుకులే అనుకుని ఊరుకున్నాడు.ఇంతలో వెనక నుంచి “దొంగ! దొంగా!” అని అరుపులు వినిపించాయి. వెనక్కి తిరిగి చూస్తే కొంత మంది కోపంగా కర్రలు, కట్టెలు పట్టుకుని పరిగెత్తుకుంటూ వస్తున్నారు!“అరెరే! మన దెగ్గిర కనుక ఈ సంచి చూస్తే మనం దొరికిపోతాము. వాళ్ళు మనల్ని చితక్కోట్టేస్తారు!” అని గిరి ఖంగారుపడ్డాడు.“మనం కాదు, నువ్వు దొరికిపోతావు. నిన్ను చితక్కోట్టేస్తారు. ఈ సంచితో నాకేమి సంబంధం లేదన్నావు కదా” అని కూల్ గా రాము జవాబు చెప్పాడు.మనం ఇతర్లతో మన అదృష్టం పంచుకోనప్పుడు వాళ్ళు మన దురదృష్టంలో కలిసి వస్తారనుకోవడం మూర్ఖత్వమే కదా!
# ఒక కాకి ఎప్పుడు హంసలను చూసి కుళ్ళు కునేది. వాటి తెల్లటి రెక్కలని, అందమైన రూపాన్ని చూసి కాకి బాధ పాడేది. ఎప్పుడు “నేనూ అలా వుంటే బాగుండేది! ఇలా నల్లగా వున్నాను” అనుకుంటూ వుండేది.ఒక రోజు కాకికి ఒక మూర్ఖమైన ఆలోచన కలిగింది. హంసల లాగానే తనూ నీళ్ళల్లో ఉంటూ, వాటిలా కలుపు మొక్కలు తింటూ, చెరువులో ఈత కొడుతూ వుంటే అదీ చాలా అందంగా అయిపోతున్దనుకుంది ఆ పిచ్చి కాకి.మొన్నాటి నుంచి నానా ప్రయత్నాలు చేసింది. గాలిలో ఎగరడం మానేసి నీళ్ళల్లో ఈత కొట్టడానికి తెగ ప్రయత్నం చేసింది. కాని కాకికి ఈత రాదు కదా!అలవాటు లేని కాలుకు మొక్కలు తింటే అవి పడక, తినలేక, పాపం కాకి చిక్కి సల్యమయిపోయింది.అయినా పాపం చాలా రోజులు అలాగే ప్రయత్నం చేసింది.కాని అందంగా తయారవడము కాదు కదా, ఉన్న బలం కూడా కోలి పోయింది.ఇంక ఇది లాభం లేదని, అలవాట్లు మార్చినంత మాత్రాన్న రూపం మారిపోదని తెలుసుకుని కాకి ఆ పైన హంసలను చూసి అసూయ పాడడం మానేసింది.
# ఒక స్వార్థమైన  నక్క ఒక రోజు తన మిత్రుడు ఐన కొంగ ను తన ఇంటికి  రాత్రి భోజనానికి ఆహ్వానించింది. ఆరోజు  సాయంత్రం, కొంగ నక్కఇంటికి వెళ్లి, కొంగ తన  పొడవైన ముక్కుతో తలుపు తట్టింది. నక్క తలుపు తెరిచి, “దయచేసి లోపలికి వచ్చి నా ఆహారాన్ని పంచుకోండిమిత్రమా ” అంది.  కొంగను టేబుల్ వద్ద కూర్చోమని ఆహ్వానించింది. కొంగ చాలా ఆకలితో ఉంది మరియు ఆహారం రుచికరమైన వాసనచూసింది! నక్క రెండు ప్లేట్లలో సూప్ వడ్డించింది మరియు నక్క  తన సూప్ మొత్తాన్ని చాలా త్వరగా  తినేసింది.కొంగ  తన  పొడవైనముక్కుకు ప్లేట్ చాలా నిస్సారంగా ఉన్నందున కొంగ తినలేకపోయింది. పాపం కొంగ మర్యాదగా నవ్వి ఆకలితో ఉండిపోయింది. స్వార్థమైన  నక్క, “కొంగ, మీ సూప్ ఎందుకు తినలేదు? మీకు నచ్చలేదా? ” అని అడిగింది.. అందుకు కొంగ బదులిచ్చింది, “నన్ను విందుకుఆహ్వానించడం చాలా సంతోషం. రేపు సాయంత్రం, దయచేసి నా ఇంట్లో విందు కోసం నాతో చేరండి. ”  అని కొంగ నక్కను పిలిచింది. మరుసటి రోజు, నక్క కొంగ ఇంటికి వచ్చినప్పుడు,  విందు కోసం సూప్ చేసిందని నక్క చూసింది.  ఈసారి కొంగ సూప్ను పొడవైన జగ్గు లలోవడ్డించింది. కొంగ సూప్‌ను తేలికగా తాగింది, కాని నక్క పొడవైన కూజా లోపలికి తల వెళ్ళలేదు అందువల్ల సూప్ ను తాగలేకపోయింది. అప్పుడు నక్క తన తప్పు తెలుసుకొని తన ఇంటికి తిరిగి వెళ్ళిపోయింది.
# ఒక వేసవి కాలం ఒక కాకి చాలా దాహంతో ఉంది. అది నీటిని వెతుకుతూ వెతుకుతూ పొలాలు చెరువులు అన్ని తిరగసాగింది. కానీఎండలు బాగా ఉండడంతో చెరువులు అన్ని ఎండిపోయాయి, పొలంలో కూడా నీరు దొరకలేదు. కాకి చాలా నీరసించిపోయింది, దాదాపు“ఈ వేసవిలో నీరు దొరకడం కష్టమని ఆశలు వదులుకుంది”ఆలా ఎగురుకుంటూ చాలా దూరం పోయింది. అకస్మాత్తుగా దానికి ఒకకుండ కనబడింది. అది నేరుగా కుండ దగ్గరికి వెళ్లి కుండలో నీరు ఉందా ? లేదా! అని చూసింది. “కుండ అడుగు బాగాన  కొంత నీరుఉంది”.అది చూసిన కాకి సంతోషంతో నీరు త్రాగడానికి ప్రయత్నించింది. కానీ “కుండ అడుగు బాగాన నీరు ఉన్నందున” కాకి నీటినిఅందుకోలేకపోయింది”.నీరు కన్పించగానే ఎంతో సంతోషపడింది. కానీ త్రాగడానికి అందకపోవడంతో “అటు ఇటు చూస్తూ బాగాఆలోచించింది. కాకికి ” గులక రాళ్లు కనబడ్డాయి”. కాకికి మంచి ఆలోచన వచ్చింది వెంటనే ” గులక రాళ్ళని ఒక్కొక్కటి తీసుకొని వచ్చికుండలో వేసింది అలా కొన్ని  వేసేసరికి కుండ అడుగు బాగాన  ఉన్న నీళ్లు కాస్త పైనకి వచ్చాయి. కాకి సంతోషంహ నీటిని త్రాగింది
# 3771

# %% [markdown]
# # sentence tokenization

# %%
from indicnlp.tokenize import sentence_tokenize
sentences=sentence_tokenize.sentence_split(telugu_data, lang='te')

for t in sentences:
    print(t)
# Out:
# అనగనగా ఒక రహదారిలో రాము, గిరి అనబడే ఇద్దరు బాటసారులు కలిసి ప్రయాణం చేస్తున్నారు.
# దారిలో అనుకోకుండా గిరికి ఒక సంచి కనిపించింది.
# ఆ సంచి తెరిచి చూస్తే అందులో బంగారు నాణాలు ఉన్నాయి!
# “నేను యెంత అదృష్టవంతుడిని, నాకు అనుకోకుండా ఇంత బంగారం దొరికింది!
# ” అని గిరి రాముతో అన్నాడు.
# “నేను అదృష్టవంతుదిని అనకు, మనం అదృష్టవంతులము” అని రాము బదులు చెప్పాడు.
# “అదెలా కుదురుతుంది?
# సంచి నాకు దొరికింది కనుక బంగారమూ నాడదే, అదృష్టము నాదే!
# మనం కాదు; నేను అదృష్టవంతుడిని!
# అని గిరి కోపంగా అన్నాడు.
# రాము గొడవ పడడం ఎందుకులే అనుకుని ఊరుకున్నాడు.
# ఇంతలో వెనక నుంచి “దొంగ!
# దొంగా!
# ” అని అరుపులు వినిపించాయి.
# వెనక్కి తిరిగి చూస్తే కొంత మంది కోపంగా కర్రలు, కట్టెలు పట్టుకుని పరిగెత్తుకుంటూ వస్తున్నారు!
# “అరెరే!
# మన దెగ్గిర కనుక ఈ సంచి చూస్తే మనం దొరికిపోతాము.
# వాళ్ళు మనల్ని చితక్కోట్టేస్తారు!
# ” అని గిరి ఖంగారుపడ్డాడు.
# “మనం కాదు, నువ్వు దొరికిపోతావు.
# నిన్ను చితక్కోట్టేస్తారు.
# ఈ సంచితో నాకేమి సంబంధం లేదన్నావు కదా” అని కూల్ గా రాము జవాబు చెప్పాడు.
# మనం ఇతర్లతో మన అదృష్టం పంచుకోనప్పుడు వాళ్ళు మన దురదృష్టంలో కలిసి వస్తారనుకోవడం మూర్ఖత్వమే కదా!
# ఒక కాకి ఎప్పుడు హంసలను చూసి కుళ్ళు కునేది.
# వాటి తెల్లటి రెక్కలని, అందమైన రూపాన్ని చూసి కాకి బాధ పాడేది.
# ఎప్పుడు “నేనూ అలా వుంటే బాగుండేది!
# ఇలా నల్లగా వున్నాను” అనుకుంటూ వుండేది.
# ఒక రోజు కాకికి ఒక మూర్ఖమైన ఆలోచన కలిగింది.
# హంసల లాగానే తనూ నీళ్ళల్లో ఉంటూ, వాటిలా కలుపు మొక్కలు తింటూ, చెరువులో ఈత కొడుతూ వుంటే అదీ చాలా అందంగా అయిపోతున్దనుకుంది ఆ పిచ్చి కాకి.
# మొన్నాటి నుంచి నానా ప్రయత్నాలు చేసింది.
# గాలిలో ఎగరడం మానేసి నీళ్ళల్లో ఈత కొట్టడానికి తెగ ప్రయత్నం చేసింది.
# కాని కాకికి ఈత రాదు కదా!
# అలవాటు లేని కాలుకు మొక్కలు తింటే అవి పడక, తినలేక, పాపం కాకి చిక్కి సల్యమయిపోయింది.
# అయినా పాపం చాలా రోజులు అలాగే ప్రయత్నం చేసింది.
# కాని అందంగా తయారవడము కాదు కదా, ఉన్న బలం కూడా కోలి పోయింది.
# ఇంక ఇది లాభం లేదని, అలవాట్లు మార్చినంత మాత్రాన్న రూపం మారిపోదని తెలుసుకుని కాకి ఆ పైన హంసలను చూసి అసూయ పాడడం మానేసింది.
# ఒక స్వార్థమైన  నక్క ఒక రోజు తన మిత్రుడు ఐన కొంగ ను తన ఇంటికి  రాత్రి భోజనానికి ఆహ్వానించింది.
# ఆరోజు  సాయంత్రం, కొంగ నక్కఇంటికి వెళ్లి, కొంగ తన  పొడవైన ముక్కుతో తలుపు తట్టింది.
# నక్క తలుపు తెరిచి, “దయచేసి లోపలికి వచ్చి నా ఆహారాన్ని పంచుకోండిమిత్రమా ” అంది.
# కొంగను టేబుల్ వద్ద కూర్చోమని ఆహ్వానించింది.
# కొంగ చాలా ఆకలితో ఉంది మరియు ఆహారం రుచికరమైన వాసనచూసింది!
# నక్క రెండు ప్లేట్లలో సూప్ వడ్డించింది మరియు నక్క  తన సూప్ మొత్తాన్ని చాలా త్వరగా  తినేసింది.
# కొంగ  తన  పొడవైనముక్కుకు ప్లేట్ చాలా నిస్సారంగా ఉన్నందున కొంగ తినలేకపోయింది.
# పాపం కొంగ మర్యాదగా నవ్వి ఆకలితో ఉండిపోయింది.
# స్వార్థమైన  నక్క, “కొంగ, మీ సూప్ ఎందుకు తినలేదు?
# మీకు నచ్చలేదా?
# ” అని అడిగింది. . అందుకు కొంగ బదులిచ్చింది, “నన్ను విందుకుఆహ్వానించడం చాలా సంతోషం.
# రేపు సాయంత్రం, దయచేసి నా ఇంట్లో విందు కోసం నాతో చేరండి.
# ”  అని కొంగ నక్కను పిలిచింది.
# మరుసటి రోజు, నక్క కొంగ ఇంటికి వచ్చినప్పుడు,  విందు కోసం సూప్ చేసిందని నక్క చూసింది.
# ఈసారి కొంగ సూప్ను పొడవైన జగ్గు లలోవడ్డించింది.
# కొంగ సూప్‌ను తేలికగా తాగింది, కాని నక్క పొడవైన కూజా లోపలికి తల వెళ్ళలేదు అందువల్ల సూప్ ను తాగలేకపోయింది.
# అప్పుడు నక్క తన తప్పు తెలుసుకొని తన ఇంటికి తిరిగి వెళ్ళిపోయింది.
# ఒక వేసవి కాలం ఒక కాకి చాలా దాహంతో ఉంది.
# అది నీటిని వెతుకుతూ వెతుకుతూ పొలాలు చెరువులు అన్ని తిరగసాగింది.
# కానీఎండలు బాగా ఉండడంతో చెరువులు అన్ని ఎండిపోయాయి, పొలంలో కూడా నీరు దొరకలేదు.
# కాకి చాలా నీరసించిపోయింది, దాదాపు“ఈ వేసవిలో నీరు దొరకడం కష్టమని ఆశలు వదులుకుంది”ఆలా ఎగురుకుంటూ చాలా దూరం పోయింది.
# అకస్మాత్తుగా దానికి ఒకకుండ కనబడింది.
# అది నేరుగా కుండ దగ్గరికి వెళ్లి కుండలో నీరు ఉందా ?
# లేదా!
# అని చూసింది.
# “కుండ అడుగు బాగాన  కొంత నీరుఉంది”.
# అది చూసిన కాకి సంతోషంతో నీరు త్రాగడానికి ప్రయత్నించింది.
# కానీ “కుండ అడుగు బాగాన నీరు ఉన్నందున” కాకి నీటినిఅందుకోలేకపోయింది”.
# నీరు కన్పించగానే ఎంతో సంతోషపడింది.
# కానీ త్రాగడానికి అందకపోవడంతో “అటు ఇటు చూస్తూ బాగాఆలోచించింది.
# కాకికి ” గులక రాళ్లు కనబడ్డాయి”.
# కాకికి మంచి ఆలోచన వచ్చింది వెంటనే ” గులక రాళ్ళని ఒక్కొక్కటి తీసుకొని వచ్చికుండలో వేసింది అలా కొన్ని  వేసేసరికి కుండ అడుగు బాగాన  ఉన్న నీళ్లు కాస్త పైనకి వచ్చాయి.
# కాకి సంతోషంహ నీటిని త్రాగింది

# %% [markdown]
# # Removing number and punctuation

# %%
import re
import string

def remove_punctuation (text):
  remove_numbers = re.sub(r'\d+','',telugu_data)
  tran_te_data1 = remove_numbers.translate(t)
  translator = str.maketrans( '', '', string.punctuation)
  translator = str.maketrans( '“', ' ', string.punctuation)
  return text. translate(translator)
tran_te_data = remove_punctuation(telugu_data)
print(remove_punctuation(telugu_data))
# Out:
# అనగనగా ఒక రహదారిలో రాము గిరి అనబడే ఇద్దరు బాటసారులు కలిసి ప్రయాణం చేస్తున్నారుదారిలో అనుకోకుండా గిరికి ఒక సంచి కనిపించింది ఆ సంచి తెరిచి చూస్తే అందులో బంగారు నాణాలు ఉన్నాయి నేను యెంత అదృష్టవంతుడిని నాకు అనుకోకుండా ఇంత బంగారం దొరికింది” అని గిరి రాముతో అన్నాడు నేను అదృష్టవంతుదిని అనకు మనం అదృష్టవంతులము” అని రాము బదులు చెప్పాడు అదెలా కుదురుతుంది సంచి నాకు దొరికింది కనుక బంగారమూ నాడదే అదృష్టము నాదే మనం కాదు నేను అదృష్టవంతుడిని అని గిరి కోపంగా అన్నాడురాము గొడవ పడడం ఎందుకులే అనుకుని ఊరుకున్నాడుఇంతలో వెనక నుంచి  దొంగ దొంగా” అని అరుపులు వినిపించాయి వెనక్కి తిరిగి చూస్తే కొంత మంది కోపంగా కర్రలు కట్టెలు పట్టుకుని పరిగెత్తుకుంటూ వస్తున్నారు అరెరే మన దెగ్గిర కనుక ఈ సంచి చూస్తే మనం దొరికిపోతాము వాళ్ళు మనల్ని చితక్కోట్టేస్తారు” అని గిరి ఖంగారుపడ్డాడు మనం కాదు నువ్వు దొరికిపోతావు నిన్ను చితక్కోట్టేస్తారు ఈ సంచితో నాకేమి సంబంధం లేదన్నావు కదా” అని కూల్ గా రాము జవాబు చెప్పాడుమనం ఇతర్లతో మన అదృష్టం పంచుకోనప్పుడు వాళ్ళు మన దురదృష్టంలో కలిసి వస్తారనుకోవడం మూర్ఖత్వమే కదా
# ఒక కాకి ఎప్పుడు హంసలను చూసి కుళ్ళు కునేది వాటి తెల్లటి రెక్కలని అందమైన రూపాన్ని చూసి కాకి బాధ పాడేది ఎప్పుడు  నేనూ అలా వుంటే బాగుండేది ఇలా నల్లగా వున్నాను” అనుకుంటూ వుండేదిఒక రోజు కాకికి ఒక మూర్ఖమైన ఆలోచన కలిగింది హంసల లాగానే తనూ నీళ్ళల్లో ఉంటూ వాటిలా కలుపు మొక్కలు తింటూ చెరువులో ఈత కొడుతూ వుంటే అదీ చాలా అందంగా అయిపోతున్దనుకుంది ఆ పిచ్చి కాకిమొన్నాటి నుంచి నానా ప్రయత్నాలు చేసింది గాలిలో ఎగరడం మానేసి నీళ్ళల్లో ఈత కొట్టడానికి తెగ ప్రయత్నం చేసింది కాని కాకికి ఈత రాదు కదాఅలవాటు లేని కాలుకు మొక్కలు తింటే అవి పడక తినలేక పాపం కాకి చిక్కి సల్యమయిపోయిందిఅయినా పాపం చాలా రోజులు అలాగే ప్రయత్నం చేసిందికాని అందంగా తయారవడము కాదు కదా ఉన్న బలం కూడా కోలి పోయిందిఇంక ఇది లాభం లేదని అలవాట్లు మార్చినంత మాత్రాన్న రూపం మారిపోదని తెలుసుకుని కాకి ఆ పైన హంసలను చూసి అసూయ పాడడం మానేసింది
# ఒక స్వార్థమైన  నక్క ఒక రోజు తన మిత్రుడు ఐన కొంగ ను తన ఇంటికి  రాత్రి భోజనానికి ఆహ్వానించింది ఆరోజు  సాయంత్రం కొంగ నక్కఇంటికి వెళ్లి కొంగ తన  పొడవైన ముక్కుతో తలుపు తట్టింది నక్క తలుపు తెరిచి  దయచేసి లోపలికి వచ్చి నా ఆహారాన్ని పంచుకోండిమిత్రమా ” అంది  కొంగను టేబుల్ వద్ద కూర్చోమని ఆహ్వానించింది కొంగ చాలా ఆకలితో ఉంది మరియు ఆహారం రుచికరమైన వాసనచూసింది నక్క రెండు ప్లేట్లలో సూప్ వడ్డించింది మరియు నక్క  తన సూప్ మొత్తాన్ని చాలా త్వరగా  తినేసిందికొంగ  తన  పొడవైనముక్కుకు ప్లేట్ చాలా నిస్సారంగా ఉన్నందున కొంగ తినలేకపోయింది పాపం కొంగ మర్యాదగా నవ్వి ఆకలితో ఉండిపోయింది స్వార్థమైన  నక్క  కొంగ మీ సూప్ ఎందుకు తినలేదు మీకు నచ్చలేదా ” అని అడిగింది అందుకు కొంగ బదులిచ్చింది  నన్ను విందుకుఆహ్వానించడం చాలా సంతోషం రేపు సాయంత్రం దయచేసి నా ఇంట్లో విందు కోసం నాతో చేరండి ”  అని కొంగ నక్కను పిలిచింది మరుసటి రోజు నక్క కొంగ ఇంటికి వచ్చినప్పుడు  విందు కోసం సూప్ చేసిందని నక్క చూసింది  ఈసారి కొంగ సూప్ను పొడవైన జగ్గు లలోవడ్డించింది కొంగ సూప్‌ను తేలికగా తాగింది కాని నక్క పొడవైన కూజా లోపలికి తల వెళ్ళలేదు అందువల్ల సూప్ ను తాగలేకపోయింది అప్పుడు నక్క తన తప్పు తెలుసుకొని తన ఇంటికి తిరిగి వెళ్ళిపోయింది
# ఒక వేసవి కాలం ఒక కాకి చాలా దాహంతో ఉంది అది నీటిని వెతుకుతూ వెతుకుతూ పొలాలు చెరువులు అన్ని తిరగసాగింది కానీఎండలు బాగా ఉండడంతో చెరువులు అన్ని ఎండిపోయాయి పొలంలో కూడా నీరు దొరకలేదు కాకి చాలా నీరసించిపోయింది దాదాపు ఈ వేసవిలో నీరు దొరకడం కష్టమని ఆశలు వదులుకుంది”ఆలా ఎగురుకుంటూ చాలా దూరం పోయింది అకస్మాత్తుగా దానికి ఒకకుండ కనబడింది అది నేరుగా కుండ దగ్గరికి వెళ్లి కుండలో నీరు ఉందా  లేదా అని చూసింది  కుండ అడుగు బాగాన  కొంత నీరుఉంది”అది చూసిన కాకి సంతోషంతో నీరు త్రాగడానికి ప్రయత్నించింది కానీ  కుండ అడుగు బాగాన నీరు ఉన్నందున” కాకి నీటినిఅందుకోలేకపోయింది”నీరు కన్పించగానే ఎంతో సంతోషపడింది కానీ త్రాగడానికి అందకపోవడంతో  అటు ఇటు చూస్తూ బాగాఆలోచించింది కాకికి ” గులక రాళ్లు కనబడ్డాయి” కాకికి మంచి ఆలోచన వచ్చింది వెంటనే ” గులక రాళ్ళని ఒక్కొక్కటి తీసుకొని వచ్చికుండలో వేసింది అలా కొన్ని  వేసేసరికి కుండ అడుగు బాగాన  ఉన్న నీళ్లు కాస్త పైనకి వచ్చాయి కాకి సంతోషంహ నీటిని త్రాగింది

# %% [markdown]
# # Word tokenization

# %%
from indicnlp.tokenize import indic_tokenize  
print('Telugu word tokenzation: ')
for tel_word in indic_tokenize.trivial_tokenize(tran_te_data): 
    print(tel_word)
# Out:
# Telugu word tokenzation:
# అనగనగా
# ఒక
# రహదారిలో
# రాము
# గిరి
# అనబడే
# ఇద్దరు
# బాటసారులు
# కలిసి
# ప్రయాణం
# చేస్తున్నారుదారిలో
# అనుకోకుండా
# గిరికి
# ఒక
# సంచి
# కనిపించింది
# ఆ
# సంచి
# తెరిచి
# చూస్తే
# అందులో
# బంగారు
# నాణాలు
# ఉన్నాయి
# నేను
# యెంత
# అదృష్టవంతుడిని
# నాకు
# అనుకోకుండా
# ఇంత
# బంగారం
# దొరికింది”
# అని
# గిరి
# రాముతో
# అన్నాడు
# నేను
# అదృష్టవంతుదిని
# అనకు
# మనం
# అదృష్టవంతులము”
# అని
# రాము
# బదులు
# చెప్పాడు
# అదెలా
# కుదురుతుంది
# సంచి
# నాకు
# దొరికింది
# కనుక
# బంగారమూ
# నాడదే
# అదృష్టము
# నాదే
# మనం
# కాదు
# నేను
# అదృష్టవంతుడిని
# అని
# గిరి
# కోపంగా
# అన్నాడురాము
# గొడవ
# పడడం
# ఎందుకులే
# అనుకుని
# ఊరుకున్నాడుఇంతలో
# వెనక
# నుంచి
# దొంగ
# దొంగా”
# అని
# అరుపులు
# వినిపించాయి
# వెనక్కి
# తిరిగి
# చూస్తే
# కొంత
# మంది
# కోపంగా
# కర్రలు
# కట్టెలు
# పట్టుకుని
# పరిగెత్తుకుంటూ
# వస్తున్నారు
# అరెరే
# మన
# దెగ్గిర
# కనుక
# ఈ
# సంచి
# చూస్తే
# మనం
# దొరికిపోతాము
# వాళ్ళు
# మనల్ని
# చితక్కోట్టేస్తారు”
# అని
# గిరి
# ఖంగారుపడ్డాడు
# మనం
# కాదు
# నువ్వు
# దొరికిపోతావు
# నిన్ను
# చితక్కోట్టేస్తారు
# ఈ
# సంచితో
# నాకేమి
# సంబంధం
# లేదన్నావు
# కదా”
# అని
# కూల్
# గా
# రాము
# జవాబు
# చెప్పాడుమనం
# ఇతర్లతో
# మన
# అదృష్టం
# పంచుకోనప్పుడు
# వాళ్ళు
# మన
# దురదృష్టంలో
# కలిసి
# వస్తారనుకోవడం
# మూర్ఖత్వమే
# కదా
# ఒక
# కాకి
# ఎప్పుడు
# హంసలను
# చూసి
# కుళ్ళు
# కునేది
# వాటి
# తెల్లటి
# రెక్కలని
# అందమైన
# రూపాన్ని
# చూసి
# కాకి
# బాధ
# పాడేది
# ఎప్పుడు
# నేనూ
# అలా
# వుంటే
# బాగుండేది
# ఇలా
# నల్లగా
# వున్నాను”
# అనుకుంటూ
# వుండేదిఒక
# రోజు
# కాకికి
# ఒక
# మూర్ఖమైన
# ఆలోచన
# కలిగింది
# హంసల
# లాగానే
# తనూ
# నీళ్ళల్లో
# ఉంటూ
# వాటిలా
# కలుపు
# మొక్కలు
# తింటూ
# చెరువులో
# ఈత
# కొడుతూ
# వుంటే
# అదీ
# చాలా
# అందంగా
# అయిపోతున్దనుకుంది
# ఆ
# పిచ్చి
# కాకిమొన్నాటి
# నుంచి
# నానా
# ప్రయత్నాలు
# చేసింది
# గాలిలో
# ఎగరడం
# మానేసి
# నీళ్ళల్లో
# ఈత
# కొట్టడానికి
# తెగ
# ప్రయత్నం
# చేసింది
# కాని
# కాకికి
# ఈత
# రాదు
# కదాఅలవాటు
# లేని
# కాలుకు
# మొక్కలు
# తింటే
# అవి
# పడక
# తినలేక
# పాపం
# కాకి
# చిక్కి
# సల్యమయిపోయిందిఅయినా
# పాపం
# చాలా
# రోజులు
# అలాగే
# ప్రయత్నం
# చేసిందికాని
# అందంగా
# తయారవడము
# కాదు
# కదా
# ఉన్న
# బలం
# కూడా
# కోలి
# పోయిందిఇంక
# ఇది
# లాభం
# లేదని
# అలవాట్లు
# మార్చినంత
# మాత్రాన్న
# రూపం
# మారిపోదని
# తెలుసుకుని
# కాకి
# ఆ
# పైన
# హంసలను
# చూసి
# అసూయ
# పాడడం
# మానేసింది
# ఒక
# స్వార్థమైన
# నక్క
# ఒక
# రోజు
# తన
# మిత్రుడు
# ఐన
# కొంగ
# ను
# తన
# ఇంటికి
# రాత్రి
# భోజనానికి
# ఆహ్వానించింది
# ఆరోజు
# సాయంత్రం
# కొంగ
# నక్కఇంటికి
# వెళ్లి
# కొంగ
# తన
# పొడవైన
# ముక్కుతో
# తలుపు
# తట్టింది
# నక్క
# తలుపు
# తెరిచి
# దయచేసి
# లోపలికి
# వచ్చి
# నా
# ఆహారాన్ని
# పంచుకోండిమిత్రమా
# ”
# అంది
# కొంగను
# టేబుల్
# వద్ద
# కూర్చోమని
# ఆహ్వానించింది
# కొంగ
# చాలా
# ఆకలితో
# ఉంది
# మరియు
# ఆహారం
# రుచికరమైన
# వాసనచూసింది
# నక్క
# రెండు
# ప్లేట్లలో
# సూప్
# వడ్డించింది
# మరియు
# నక్క
# తన
# సూప్
# మొత్తాన్ని
# చాలా
# త్వరగా
# తినేసిందికొంగ
# తన
# పొడవైనముక్కుకు
# ప్లేట్
# చాలా
# నిస్సారంగా
# ఉన్నందున
# కొంగ
# తినలేకపోయింది
# పాపం
# కొంగ
# మర్యాదగా
# నవ్వి
# ఆకలితో
# ఉండిపోయింది
# స్వార్థమైన
# నక్క
# కొంగ
# మీ
# సూప్
# ఎందుకు
# తినలేదు
# మీకు
# నచ్చలేదా
# ”
# అని
# అడిగింది
# అందుకు
# కొంగ
# బదులిచ్చింది
# నన్ను
# విందుకుఆహ్వానించడం
# చాలా
# సంతోషం
# రేపు
# సాయంత్రం
# దయచేసి
# నా
# ఇంట్లో
# విందు
# కోసం
# నాతో
# చేరండి
# ”
# అని
# కొంగ
# నక్కను
# పిలిచింది
# మరుసటి
# రోజు
# నక్క
# కొంగ
# ఇంటికి
# వచ్చినప్పుడు
# విందు
# కోసం
# సూప్
# చేసిందని
# నక్క
# చూసింది
# ఈసారి
# కొంగ
# సూప్ను
# పొడవైన
# జగ్గు
# లలోవడ్డించింది
# కొంగ
# సూప్‌ను
# తేలికగా
# తాగింది
# కాని
# నక్క
# పొడవైన
# కూజా
# లోపలికి
# తల
# వెళ్ళలేదు
# అందువల్ల
# సూప్
# ను
# తాగలేకపోయింది
# అప్పుడు
# నక్క
# తన
# తప్పు
# తెలుసుకొని
# తన
# ఇంటికి
# తిరిగి
# వెళ్ళిపోయింది
# ఒక
# వేసవి
# కాలం
# ఒక
# కాకి
# చాలా
# దాహంతో
# ఉంది
# అది
# నీటిని
# వెతుకుతూ
# వెతుకుతూ
# పొలాలు
# చెరువులు
# అన్ని
# తిరగసాగింది
# కానీఎండలు
# బాగా
# ఉండడంతో
# చెరువులు
# అన్ని
# ఎండిపోయాయి
# పొలంలో
# కూడా
# నీరు
# దొరకలేదు
# కాకి
# చాలా
# నీరసించిపోయింది
# దాదాపు
# ఈ
# వేసవిలో
# నీరు
# దొరకడం
# కష్టమని
# ఆశలు
# వదులుకుంది”ఆలా
# ఎగురుకుంటూ
# చాలా
# దూరం
# పోయింది
# అకస్మాత్తుగా
# దానికి
# ఒకకుండ
# కనబడింది
# అది
# నేరుగా
# కుండ
# దగ్గరికి
# వెళ్లి
# కుండలో
# నీరు
# ఉందా
# లేదా
# అని
# చూసింది
# కుండ
# అడుగు
# బాగాన
# కొంత
# నీరుఉంది”అది
# చూసిన
# కాకి
# సంతోషంతో
# నీరు
# త్రాగడానికి
# ప్రయత్నించింది
# కానీ
# కుండ
# అడుగు
# బాగాన
# నీరు
# ఉన్నందున”
# కాకి
# నీటినిఅందుకోలేకపోయింది”నీరు
# కన్పించగానే
# ఎంతో
# సంతోషపడింది
# కానీ
# త్రాగడానికి
# అందకపోవడంతో
# అటు
# ఇటు
# చూస్తూ
# బాగాఆలోచించింది
# కాకికి
# ”
# గులక
# రాళ్లు
# కనబడ్డాయి”
# కాకికి
# మంచి
# ఆలోచన
# వచ్చింది
# వెంటనే
# ”
# గులక
# రాళ్ళని
# ఒక్కొక్కటి
# తీసుకొని
# వచ్చికుండలో
# వేసింది
# అలా
# కొన్ని
# వేసేసరికి
# కుండ
# అడుగు
# బాగాన
# ఉన్న
# నీళ్లు
# కాస్త
# పైనకి
# వచ్చాయి
# కాకి
# సంతోషంహ
# నీటిని
# త్రాగింది

# %% [markdown]
# # Stemming with porterStemmer

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
ps = PorterStemmer()
for ts in tran_te_data:
  print(ts, ':', ps.stem(ts))
# Out:
# అ : అ
# న : న
# గ : గ
# న : న
# గ : గ
# ా : ా
#   :
# ఒ : ఒ
# క : క
#   :
# ర : ర
# హ : హ
# ద : ద
# ా : ా
# ర : ర
# ి : ి
# ల : ల
# ో : ో
#   :
# ర : ర
# ా : ా
# మ : మ
# ు : ు
#   :
# గ : గ
# ి : ి
# ర : ర
# ి : ి
#   :
# అ : అ
# న : న
# బ : బ
# డ : డ
# ే : ే
#   :
# ఇ : ఇ
# ద : ద
# ్ : ్
# ద : ద
# ర : ర
# ు : ు
#   :
# బ : బ
# ా : ా
# ట : ట
# స : స
# ా : ా
# ర : ర
# ు : ు
# ల : ల
# ు : ు
#   :
# క : క
# ల : ల
# ి : ి
# స : స
# ి : ి
#   :
# ప : ప
# ్ : ్
# ర : ర
# య : య
# ా : ా
# ణ : ణ
# ం : ం
#   :
# చ : చ
# ే : ే
# స : స
# ్ : ్
# త : త
# ు : ు
# న : న
# ్ : ్
# న : న
# ా : ా
# ర : ర
# ు : ు
# ద : ద
# ా : ా
# ర : ర
# ి : ి
# ల : ల
# ో : ో
#   :
# అ : అ
# న : న
# ు : ు
# క : క
# ో : ో
# క : క
# ు : ు
# ం : ం
# డ : డ
# ా : ా
#   :
# గ : గ
# ి : ి
# ర : ర
# ి : ి
# క : క
# ి : ి
#   :
# ఒ : ఒ
# క : క
#   :
# స : స
# ం : ం
# చ : చ
# ి : ి
#   :
# క : క
# న : న
# ి : ి
# ప : ప
# ి : ి
# ం : ం
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# ఆ : ఆ
#   :
# స : స
# ం : ం
# చ : చ
# ి : ి
#   :
# త : త
# ె : ె
# ర : ర
# ి : ి
# చ : చ
# ి : ి
#   :
# చ : చ
# ూ : ూ
# స : స
# ్ : ్
# త : త
# ే : ే
#   :
# అ : అ
# ం : ం
# ద : ద
# ు : ు
# ల : ల
# ో : ో
#   :
# బ : బ
# ం : ం
# గ : గ
# ా : ా
# ర : ర
# ు : ు
#   :
# న : న
# ా : ా
# ణ : ణ
# ా : ా
# ల : ల
# ు : ు
#   :
# ఉ : ఉ
# న : న
# ్ : ్
# న : న
# ా : ా
# య : య
# ి : ి
#   :
# న : న
# ే : ే
# న : న
# ు : ు
#   :
# య : య
# ె : ె
# ం : ం
# త : త
#   :
# అ : అ
# ద : ద
# ృ : ృ
# ష : ష
# ్ : ్
# ట : ట
# వ : వ
# ం : ం
# త : త
# ు : ు
# డ : డ
# ి : ి
# న : న
# ి : ి
#   :
# న : న
# ా : ా
# క : క
# ు : ు
#   :
# అ : అ
# న : న
# ు : ు
# క : క
# ో : ో
# క : క
# ు : ు
# ం : ం
# డ : డ
# ా : ా
#   :
# ఇ : ఇ
# ం : ం
# త : త
#   :
# బ : బ
# ం : ం
# గ : గ
# ా : ా
# ర : ర
# ం : ం
#   :
# ద : ద
# ొ : ొ
# ర : ర
# ి : ి
# క : క
# ి : ి
# ం : ం
# ద : ద
# ి : ి
# ” : ”
#   :
# అ : అ
# న : న
# ి : ి
#   :
# గ : గ
# ి : ి
# ర : ర
# ి : ి
#   :
# ర : ర
# ా : ా
# మ : మ
# ు : ు
# త : త
# ో : ో
#   :
# అ : అ
# న : న
# ్ : ్
# న : న
# ా : ా
# డ : డ
# ు : ు
#   :
# న : న
# ే : ే
# న : న
# ు : ు
#   :
# అ : అ
# ద : ద
# ృ : ృ
# ష : ష
# ్ : ్
# ట : ట
# వ : వ
# ం : ం
# త : త
# ు : ు
# ద : ద
# ి : ి
# న : న
# ి : ి
#   :
# అ : అ
# న : న
# క : క
# ు : ు
#   :
# మ : మ
# న : న
# ం : ం
#   :
# అ : అ
# ద : ద
# ృ : ృ
# ష : ష
# ్ : ్
# ట : ట
# వ : వ
# ం : ం
# త : త
# ు : ు
# ల : ల
# మ : మ
# ు : ు
# ” : ”
#   :
# అ : అ
# న : న
# ి : ి
#   :
# ర : ర
# ా : ా
# మ : మ
# ు : ు
#   :
# బ : బ
# ద : ద
# ు : ు
# ల : ల
# ు : ు
#   :
# చ : చ
# ె : ె
# ప : ప
# ్ : ్
# ప : ప
# ా : ా
# డ : డ
# ు : ు
#   :
# అ : అ
# ద : ద
# ె : ె
# ల : ల
# ా : ా
#   :
# క : క
# ు : ు
# ద : ద
# ు : ు
# ర : ర
# ు : ు
# త : త
# ు : ు
# ం : ం
# ద : ద
# ి : ి
#   :
# స : స
# ం : ం
# చ : చ
# ి : ి
#   :
# న : న
# ా : ా
# క : క
# ు : ు
#   :
# ద : ద
# ొ : ొ
# ర : ర
# ి : ి
# క : క
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# న : న
# ు : ు
# క : క
#   :
# బ : బ
# ం : ం
# గ : గ
# ా : ా
# ర : ర
# మ : మ
# ూ : ూ
#   :
# న : న
# ా : ా
# డ : డ
# ద : ద
# ే : ే
#   :
# అ : అ
# ద : ద
# ృ : ృ
# ష : ష
# ్ : ్
# ట : ట
# మ : మ
# ు : ు
#   :
# న : న
# ా : ా
# ద : ద
# ే : ే
#   :
# మ : మ
# న : న
# ం : ం
#   :
# క : క
# ా : ా
# ద : ద
# ు : ు
#   :
# న : న
# ే : ే
# న : న
# ు : ు
#   :
# అ : అ
# ద : ద
# ృ : ృ
# ష : ష
# ్ : ్
# ట : ట
# వ : వ
# ం : ం
# త : త
# ు : ు
# డ : డ
# ి : ి
# న : న
# ి : ి
#   :
# అ : అ
# న : న
# ి : ి
#   :
# గ : గ
# ి : ి
# ర : ర
# ి : ి
#   :
# క : క
# ో : ో
# ప : ప
# ం : ం
# గ : గ
# ా : ా
#   :
# అ : అ
# న : న
# ్ : ్
# న : న
# ా : ా
# డ : డ
# ు : ు
# ర : ర
# ా : ా
# మ : మ
# ు : ు
#   :
# గ : గ
# ొ : ొ
# డ : డ
# వ : వ
#   :
# ప : ప
# డ : డ
# డ : డ
# ం : ం
#   :
# ఎ : ఎ
# ం : ం
# ద : ద
# ు : ు
# క : క
# ు : ు
# ల : ల
# ే : ే
#   :
# అ : అ
# న : న
# ు : ు
# క : క
# ు : ు
# న : న
# ి : ి
#   :
# ఊ : ఊ
# ర : ర
# ు : ు
# క : క
# ు : ు
# న : న
# ్ : ్
# న : న
# ా : ా
# డ : డ
# ు : ు
# ఇ : ఇ
# ం : ం
# త : త
# ల : ల
# ో : ో
#   :
# వ : వ
# ె : ె
# న : న
# క : క
#   :
# న : న
# ు : ు
# ం : ం
# చ : చ
# ి : ి
#   :
#   :
# ద : ద
# ొ : ొ
# ం : ం
# గ : గ
#   :
# ద : ద
# ొ : ొ
# ం : ం
# గ : గ
# ా : ా
# ” : ”
#   :
# అ : అ
# న : న
# ి : ి
#   :
# అ : అ
# ర : ర
# ు : ు
# ప : ప
# ు : ు
# ల : ల
# ు : ు
#   :
# వ : వ
# ి : ి
# న : న
# ి : ి
# ప : ప
# ి : ి
# ం : ం
# చ : చ
# ా : ా
# య : య
# ి : ి
#   :
# వ : వ
# ె : ె
# న : న
# క : క
# ్ : ్
# క : క
# ి : ి
#   :
# త : త
# ి : ి
# ర : ర
# ి : ి
# గ : గ
# ి : ి
#   :
# చ : చ
# ూ : ూ
# స : స
# ్ : ్
# త : త
# ే : ే
#   :
# క : క
# ొ : ొ
# ం : ం
# త : త
#   :
# మ : మ
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ో : ో
# ప : ప
# ం : ం
# గ : గ
# ా : ా
#   :
# క : క
# ర : ర
# ్ : ్
# ర : ర
# ల : ల
# ు : ు
#   :
# క : క
# ట : ట
# ్ : ్
# ట : ట
# ె : ె
# ల : ల
# ు : ు
#   :
# ప : ప
# ట : ట
# ్ : ్
# ట : ట
# ు : ు
# క : క
# ు : ు
# న : న
# ి : ి
#   :
# ప : ప
# ర : ర
# ి : ి
# గ : గ
# ె : ె
# త : త
# ్ : ్
# త : త
# ు : ు
# క : క
# ు : ు
# ం : ం
# ట : ట
# ూ : ూ
#   :
# వ : వ
# స : స
# ్ : ్
# త : త
# ు : ు
# న : న
# ్ : ్
# న : న
# ా : ా
# ర : ర
# ు : ు
#   :
# అ : అ
# ర : ర
# ె : ె
# ర : ర
# ే : ే
#   :
# మ : మ
# న : న
#   :
# ద : ద
# ె : ె
# గ : గ
# ్ : ్
# గ : గ
# ి : ి
# ర : ర
#   :
# క : క
# న : న
# ు : ు
# క : క
#   :
# ఈ : ఈ
#   :
# స : స
# ం : ం
# చ : చ
# ి : ి
#   :
# చ : చ
# ూ : ూ
# స : స
# ్ : ్
# త : త
# ే : ే
#   :
# మ : మ
# న : న
# ం : ం
#   :
# ద : ద
# ొ : ొ
# ర : ర
# ి : ి
# క : క
# ి : ి
# ప : ప
# ో : ో
# త : త
# ా : ా
# మ : మ
# ు : ు
#   :
# వ : వ
# ా : ా
# ళ : ళ
# ్ : ్
# ళ : ళ
# ు : ు
#   :
# మ : మ
# న : న
# ల : ల
# ్ : ్
# న : న
# ి : ి
#   :
# చ : చ
# ి : ి
# త : త
# క : క
# ్ : ్
# క : క
# ో : ో
# ట : ట
# ్ : ్
# ట : ట
# ే : ే
# స : స
# ్ : ్
# త : త
# ా : ా
# ర : ర
# ు : ు
# ” : ”
#   :
# అ : అ
# న : న
# ి : ి
#   :
# గ : గ
# ి : ి
# ర : ర
# ి : ి
#   :
# ఖ : ఖ
# ం : ం
# గ : గ
# ా : ా
# ర : ర
# ు : ు
# ప : ప
# డ : డ
# ్ : ్
# డ : డ
# ా : ా
# డ : డ
# ు : ు
#   :
# మ : మ
# న : న
# ం : ం
#   :
# క : క
# ా : ా
# ద : ద
# ు : ు
#   :
# న : న
# ు : ు
# వ : వ
# ్ : ్
# వ : వ
# ు : ు
#   :
# ద : ద
# ొ : ొ
# ర : ర
# ి : ి
# క : క
# ి : ి
# ప : ప
# ో : ో
# త : త
# ా : ా
# వ : వ
# ు : ు
#   :
# న : న
# ి : ి
# న : న
# ్ : ్
# న : న
# ు : ు
#   :
# చ : చ
# ి : ి
# త : త
# క : క
# ్ : ్
# క : క
# ో : ో
# ట : ట
# ్ : ్
# ట : ట
# ే : ే
# స : స
# ్ : ్
# త : త
# ా : ా
# ర : ర
# ు : ు
#   :
# ఈ : ఈ
#   :
# స : స
# ం : ం
# చ : చ
# ి : ి
# త : త
# ో : ో
#   :
# న : న
# ా : ా
# క : క
# ే : ే
# మ : మ
# ి : ి
#   :
# స : స
# ం : ం
# బ : బ
# ం : ం
# ధ : ధ
# ం : ం
#   :
# ల : ల
# ే : ే
# ద : ద
# న : న
# ్ : ్
# న : న
# ా : ా
# వ : వ
# ు : ు
#   :
# క : క
# ద : ద
# ా : ా
# ” : ”
#   :
# అ : అ
# న : న
# ి : ి
#   :
# క : క
# ూ : ూ
# ల : ల
# ్ : ్
#   :
# గ : గ
# ా : ా
#   :
# ర : ర
# ా : ా
# మ : మ
# ు : ు
#   :
# జ : జ
# వ : వ
# ా : ా
# బ : బ
# ు : ు
#   :
# చ : చ
# ె : ె
# ప : ప
# ్ : ్
# ప : ప
# ా : ా
# డ : డ
# ు : ు
# మ : మ
# న : న
# ం : ం
#   :
# ఇ : ఇ
# త : త
# ర : ర
# ్ : ్
# ల : ల
# త : త
# ో : ో
#   :
# మ : మ
# న : న
#   :
# అ : అ
# ద : ద
# ృ : ృ
# ష : ష
# ్ : ్
# ట : ట
# ం : ం
#   :
# ప : ప
# ం : ం
# చ : చ
# ు : ు
# క : క
# ో : ో
# న : న
# ప : ప
# ్ : ్
# ప : ప
# ు : ు
# డ : డ
# ు : ు
#   :
# వ : వ
# ా : ా
# ళ : ళ
# ్ : ్
# ళ : ళ
# ు : ు
#   :
# మ : మ
# న : న
#   :
# ద : ద
# ు : ు
# ర : ర
# ద : ద
# ృ : ృ
# ష : ష
# ్ : ్
# ట : ట
# ం : ం
# ల : ల
# ో : ో
#   :
# క : క
# ల : ల
# ి : ి
# స : స
# ి : ి
#   :
# వ : వ
# స : స
# ్ : ్
# త : త
# ా : ా
# ర : ర
# న : న
# ు : ు
# క : క
# ో : ో
# వ : వ
# డ : డ
# ం : ం
#   :
# మ : మ
# ూ : ూ
# ర : ర
# ్ : ్
# ఖ : ఖ
# త : త
# ్ : ్
# వ : వ
# మ : మ
# ే : ే
#   :
# క : క
# ద : ద
# ా : ా
#
#  :
#
# ఒ : ఒ
# క : క
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# ఎ : ఎ
# ప : ప
# ్ : ్
# ప : ప
# ు : ు
# డ : డ
# ు : ు
#   :
# హ : హ
# ం : ం
# స : స
# ల : ల
# న : న
# ు : ు
#   :
# చ : చ
# ూ : ూ
# స : స
# ి : ి
#   :
# క : క
# ు : ు
# ళ : ళ
# ్ : ్
# ళ : ళ
# ు : ు
#   :
# క : క
# ు : ు
# న : న
# ే : ే
# ద : ద
# ి : ి
#   :
# వ : వ
# ా : ా
# ట : ట
# ి : ి
#   :
# త : త
# ె : ె
# ల : ల
# ్ : ్
# ల : ల
# ట : ట
# ి : ి
#   :
# ర : ర
# ె : ె
# క : క
# ్ : ్
# క : క
# ల : ల
# న : న
# ి : ి
#   :
# అ : అ
# ం : ం
# ద : ద
# మ : మ
# ై : ై
# న : న
#   :
# ర : ర
# ూ : ూ
# ప : ప
# ా : ా
# న : న
# ్ : ్
# న : న
# ి : ి
#   :
# చ : చ
# ూ : ూ
# స : స
# ి : ి
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# బ : బ
# ా : ా
# ధ : ధ
#   :
# ప : ప
# ా : ా
# డ : డ
# ే : ే
# ద : ద
# ి : ి
#   :
# ఎ : ఎ
# ప : ప
# ్ : ్
# ప : ప
# ు : ు
# డ : డ
# ు : ు
#   :
#   :
# న : న
# ే : ే
# న : న
# ూ : ూ
#   :
# అ : అ
# ల : ల
# ా : ా
#   :
# వ : వ
# ు : ు
# ం : ం
# ట : ట
# ే : ే
#   :
# బ : బ
# ా : ా
# గ : గ
# ు : ు
# ం : ం
# డ : డ
# ే : ే
# ద : ద
# ి : ి
#   :
# ఇ : ఇ
# ల : ల
# ా : ా
#   :
# న : న
# ల : ల
# ్ : ్
# ల : ల
# గ : గ
# ా : ా
#   :
# వ : వ
# ు : ు
# న : న
# ్ : ్
# న : న
# ా : ా
# న : న
# ు : ు
# ” : ”
#   :
# అ : అ
# న : న
# ు : ు
# క : క
# ు : ు
# ం : ం
# ట : ట
# ూ : ూ
#   :
# వ : వ
# ు : ు
# ం : ం
# డ : డ
# ే : ే
# ద : ద
# ి : ి
# ఒ : ఒ
# క : క
#   :
# ర : ర
# ో : ో
# జ : జ
# ు : ు
#   :
# క : క
# ా : ా
# క : క
# ి : ి
# క : క
# ి : ి
#   :
# ఒ : ఒ
# క : క
#   :
# మ : మ
# ూ : ూ
# ర : ర
# ్ : ్
# ఖ : ఖ
# మ : మ
# ై : ై
# న : న
#   :
# ఆ : ఆ
# ల : ల
# ో : ో
# చ : చ
# న : న
#   :
# క : క
# ల : ల
# ి : ి
# గ : గ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# హ : హ
# ం : ం
# స : స
# ల : ల
#   :
# ల : ల
# ా : ా
# గ : గ
# ా : ా
# న : న
# ే : ే
#   :
# త : త
# న : న
# ూ : ూ
#   :
# న : న
# ీ : ీ
# ళ : ళ
# ్ : ్
# ళ : ళ
# ల : ల
# ్ : ్
# ల : ల
# ో : ో
#   :
# ఉ : ఉ
# ం : ం
# ట : ట
# ూ : ూ
#   :
# వ : వ
# ా : ా
# ట : ట
# ి : ి
# ల : ల
# ా : ా
#   :
# క : క
# ల : ల
# ు : ు
# ప : ప
# ు : ు
#   :
# మ : మ
# ొ : ొ
# క : క
# ్ : ్
# క : క
# ల : ల
# ు : ు
#   :
# త : త
# ి : ి
# ం : ం
# ట : ట
# ూ : ూ
#   :
# చ : చ
# ె : ె
# ర : ర
# ు : ు
# వ : వ
# ు : ు
# ల : ల
# ో : ో
#   :
# ఈ : ఈ
# త : త
#   :
# క : క
# ొ : ొ
# డ : డ
# ు : ు
# త : త
# ూ : ూ
#   :
# వ : వ
# ు : ు
# ం : ం
# ట : ట
# ే : ే
#   :
# అ : అ
# ద : ద
# ీ : ీ
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# అ : అ
# ం : ం
# ద : ద
# ం : ం
# గ : గ
# ా : ా
#   :
# అ : అ
# య : య
# ి : ి
# ప : ప
# ో : ో
# త : త
# ు : ు
# న : న
# ్ : ్
# ద : ద
# న : న
# ు : ు
# క : క
# ు : ు
# ం : ం
# ద : ద
# ి : ి
#   :
# ఆ : ఆ
#   :
# ప : ప
# ి : ి
# చ : చ
# ్ : ్
# చ : చ
# ి : ి
#   :
# క : క
# ా : ా
# క : క
# ి : ి
# మ : మ
# ొ : ొ
# న : న
# ్ : ్
# న : న
# ా : ా
# ట : ట
# ి : ి
#   :
# న : న
# ు : ు
# ం : ం
# చ : చ
# ి : ి
#   :
# న : న
# ా : ా
# న : న
# ా : ా
#   :
# ప : ప
# ్ : ్
# ర : ర
# య : య
# త : త
# ్ : ్
# న : న
# ా : ా
# ల : ల
# ు : ు
#   :
# చ : చ
# ే : ే
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# గ : గ
# ా : ా
# ల : ల
# ి : ి
# ల : ల
# ో : ో
#   :
# ఎ : ఎ
# గ : గ
# ర : ర
# డ : డ
# ం : ం
#   :
# మ : మ
# ా : ా
# న : న
# ే : ే
# స : స
# ి : ి
#   :
# న : న
# ీ : ీ
# ళ : ళ
# ్ : ్
# ళ : ళ
# ల : ల
# ్ : ్
# ల : ల
# ో : ో
#   :
# ఈ : ఈ
# త : త
#   :
# క : క
# ొ : ొ
# ట : ట
# ్ : ్
# ట : ట
# డ : డ
# ా : ా
# న : న
# ి : ి
# క : క
# ి : ి
#   :
# త : త
# ె : ె
# గ : గ
#   :
# ప : ప
# ్ : ్
# ర : ర
# య : య
# త : త
# ్ : ్
# న : న
# ం : ం
#   :
# చ : చ
# ే : ే
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ా : ా
# న : న
# ి : ి
#   :
# క : క
# ా : ా
# క : క
# ి : ి
# క : క
# ి : ి
#   :
# ఈ : ఈ
# త : త
#   :
# ర : ర
# ా : ా
# ద : ద
# ు : ు
#   :
# క : క
# ద : ద
# ా : ా
# అ : అ
# ల : ల
# వ : వ
# ా : ా
# ట : ట
# ు : ు
#   :
# ల : ల
# ే : ే
# న : న
# ి : ి
#   :
# క : క
# ా : ా
# ల : ల
# ు : ు
# క : క
# ు : ు
#   :
# మ : మ
# ొ : ొ
# క : క
# ్ : ్
# క : క
# ల : ల
# ు : ు
#   :
# త : త
# ి : ి
# ం : ం
# ట : ట
# ే : ే
#   :
# అ : అ
# వ : వ
# ి : ి
#   :
# ప : ప
# డ : డ
# క : క
#   :
# త : త
# ి : ి
# న : న
# ల : ల
# ే : ే
# క : క
#   :
# ప : ప
# ా : ా
# ప : ప
# ం : ం
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# చ : చ
# ి : ి
# క : క
# ్ : ్
# క : క
# ి : ి
#   :
# స : స
# ల : ల
# ్ : ్
# య : య
# మ : మ
# య : య
# ి : ి
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
# అ : అ
# య : య
# ి : ి
# న : న
# ా : ా
#   :
# ప : ప
# ా : ా
# ప : ప
# ం : ం
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# ర : ర
# ో : ో
# జ : జ
# ు : ు
# ల : ల
# ు : ు
#   :
# అ : అ
# ల : ల
# ా : ా
# గ : గ
# ే : ే
#   :
# ప : ప
# ్ : ్
# ర : ర
# య : య
# త : త
# ్ : ్
# న : న
# ం : ం
#   :
# చ : చ
# ే : ే
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
# క : క
# ా : ా
# న : న
# ి : ి
#   :
# అ : అ
# ం : ం
# ద : ద
# ం : ం
# గ : గ
# ా : ా
#   :
# త : త
# య : య
# ా : ా
# ర : ర
# వ : వ
# డ : డ
# మ : మ
# ు : ు
#   :
# క : క
# ా : ా
# ద : ద
# ు : ు
#   :
# క : క
# ద : ద
# ా : ా
#   :
# ఉ : ఉ
# న : న
# ్ : ్
# న : న
#   :
# బ : బ
# ల : ల
# ం : ం
#   :
# క : క
# ూ : ూ
# డ : డ
# ా : ా
#   :
# క : క
# ో : ో
# ల : ల
# ి : ి
#   :
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
# ఇ : ఇ
# ం : ం
# క : క
#   :
# ఇ : ఇ
# ద : ద
# ి : ి
#   :
# ల : ల
# ా : ా
# భ : భ
# ం : ం
#   :
# ల : ల
# ే : ే
# ద : ద
# న : న
# ి : ి
#   :
# అ : అ
# ల : ల
# వ : వ
# ా : ా
# ట : ట
# ్ : ్
# ల : ల
# ు : ు
#   :
# మ : మ
# ా : ా
# ర : ర
# ్ : ్
# చ : చ
# ి : ి
# న : న
# ం : ం
# త : త
#   :
# మ : మ
# ా : ా
# త : త
# ్ : ్
# ర : ర
# ా : ా
# న : న
# ్ : ్
# న : న
#   :
# ర : ర
# ూ : ూ
# ప : ప
# ం : ం
#   :
# మ : మ
# ా : ా
# ర : ర
# ి : ి
# ప : ప
# ో : ో
# ద : ద
# న : న
# ి : ి
#   :
# త : త
# ె : ె
# ల : ల
# ు : ు
# స : స
# ు : ు
# క : క
# ు : ు
# న : న
# ి : ి
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# ఆ : ఆ
#   :
# ప : ప
# ై : ై
# న : న
#   :
# హ : హ
# ం : ం
# స : స
# ల : ల
# న : న
# ు : ు
#   :
# చ : చ
# ూ : ూ
# స : స
# ి : ి
#   :
# అ : అ
# స : స
# ూ : ూ
# య : య
#   :
# ప : ప
# ా : ా
# డ : డ
# డ : డ
# ం : ం
#   :
# మ : మ
# ా : ా
# న : న
# ే : ే
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#
#  :
#
# ఒ : ఒ
# క : క
#   :
# స : స
# ్ : ్
# వ : వ
# ా : ా
# ర : ర
# ్ : ్
# థ : థ
# మ : మ
# ై : ై
# న : న
#   :
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
# ఒ : ఒ
# క : క
#   :
# ర : ర
# ో : ో
# జ : జ
# ు : ు
#   :
# త : త
# న : న
#   :
# మ : మ
# ి : ి
# త : త
# ్ : ్
# ర : ర
# ు : ు
# డ : డ
# ు : ు
#   :
# ఐ : ఐ
# న : న
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# న : న
# ు : ు
#   :
# త : త
# న : న
#   :
# ఇ : ఇ
# ం : ం
# ట : ట
# ి : ి
# క : క
# ి : ి
#   :
#   :
# ర : ర
# ా : ా
# త : త
# ్ : ్
# ర : ర
# ి : ి
#   :
# భ : భ
# ో : ో
# జ : జ
# న : న
# ా : ా
# న : న
# ి : ి
# క : క
# ి : ి
#   :
# ఆ : ఆ
# హ : హ
# ్ : ్
# వ : వ
# ా : ా
# న : న
# ి : ి
# ం : ం
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# ఆ : ఆ
# ర : ర
# ో : ో
# జ : జ
# ు : ు
#   :
#   :
# స : స
# ా : ా
# య : య
# ం : ం
# త : త
# ్ : ్
# ర : ర
# ం : ం
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# న : న
# క : క
# ్ : ్
# క : క
# ఇ : ఇ
# ం : ం
# ట : ట
# ి : ి
# క : క
# ి : ి
#   :
# వ : వ
# ె : ె
# ళ : ళ
# ్ : ్
# ల : ల
# ి : ి
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# త : త
# న : న
#   :
#   :
# ప : ప
# ొ : ొ
# డ : డ
# వ : వ
# ై : ై
# న : న
#   :
# మ : మ
# ు : ు
# క : క
# ్ : ్
# క : క
# ు : ు
# త : త
# ో : ో
#   :
# త : త
# ల : ల
# ు : ు
# ప : ప
# ు : ు
#   :
# త : త
# ట : ట
# ్ : ్
# ట : ట
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
# త : త
# ల : ల
# ు : ు
# ప : ప
# ు : ు
#   :
# త : త
# ె : ె
# ర : ర
# ి : ి
# చ : చ
# ి : ి
#   :
#   :
# ద : ద
# య : య
# చ : చ
# ే : ే
# స : స
# ి : ి
#   :
# ల : ల
# ో : ో
# ప : ప
# ల : ల
# ి : ి
# క : క
# ి : ి
#   :
# వ : వ
# చ : చ
# ్ : ్
# చ : చ
# ి : ి
#   :
# న : న
# ా : ా
#   :
# ఆ : ఆ
# హ : హ
# ా : ా
# ర : ర
# ా : ా
# న : న
# ్ : ్
# న : న
# ి : ి
#   :
# ప : ప
# ం : ం
# చ : చ
# ు : ు
# క : క
# ో : ో
# ం : ం
# డ : డ
# ి : ి
# మ : మ
# ి : ి
# త : త
# ్ : ్
# ర : ర
# మ : మ
# ా : ా
#   :
# ” : ”
#   :
# అ : అ
# ం : ం
# ద : ద
# ి : ి
#   :
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
# న : న
# ు : ు
#   :
# ట : ట
# ే : ే
# బ : బ
# ు : ు
# ల : ల
# ్ : ్
#   :
# వ : వ
# ద : ద
# ్ : ్
# ద : ద
#   :
# క : క
# ూ : ూ
# ర : ర
# ్ : ్
# చ : చ
# ో : ో
# మ : మ
# న : న
# ి : ి
#   :
# ఆ : ఆ
# హ : హ
# ్ : ్
# వ : వ
# ా : ా
# న : న
# ి : ి
# ం : ం
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# ఆ : ఆ
# క : క
# ల : ల
# ి : ి
# త : త
# ో : ో
#   :
# ఉ : ఉ
# ం : ం
# ద : ద
# ి : ి
#   :
# మ : మ
# ర : ర
# ి : ి
# య : య
# ు : ు
#   :
# ఆ : ఆ
# హ : హ
# ా : ా
# ర : ర
# ం : ం
#   :
# ర : ర
# ు : ు
# చ : చ
# ి : ి
# క : క
# ర : ర
# మ : మ
# ై : ై
# న : న
#   :
# వ : వ
# ా : ా
# స : స
# న : న
# చ : చ
# ూ : ూ
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
# ర : ర
# ె : ె
# ం : ం
# డ : డ
# ు : ు
#   :
# ప : ప
# ్ : ్
# ల : ల
# ే : ే
# ట : ట
# ్ : ్
# ల : ల
# ల : ల
# ో : ో
#   :
# స : స
# ూ : ూ
# ప : ప
# ్ : ్
#   :
# వ : వ
# డ : డ
# ్ : ్
# డ : డ
# ి : ి
# ం : ం
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# మ : మ
# ర : ర
# ి : ి
# య : య
# ు : ు
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
#   :
# త : త
# న : న
#   :
# స : స
# ూ : ూ
# ప : ప
# ్ : ్
#   :
# మ : మ
# ొ : ొ
# త : త
# ్ : ్
# త : త
# ా : ా
# న : న
# ్ : ్
# న : న
# ి : ి
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# త : త
# ్ : ్
# వ : వ
# ర : ర
# గ : గ
# ా : ా
#   :
#   :
# త : త
# ి : ి
# న : న
# ే : ే
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
#   :
# త : త
# న : న
#   :
#   :
# ప : ప
# ొ : ొ
# డ : డ
# వ : వ
# ై : ై
# న : న
# మ : మ
# ు : ు
# క : క
# ్ : ్
# క : క
# ు : ు
# క : క
# ు : ు
#   :
# ప : ప
# ్ : ్
# ల : ల
# ే : ే
# ట : ట
# ్ : ్
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# న : న
# ి : ి
# స : స
# ్ : ్
# స : స
# ా : ా
# ర : ర
# ం : ం
# గ : గ
# ా : ా
#   :
# ఉ : ఉ
# న : న
# ్ : ్
# న : న
# ం : ం
# ద : ద
# ు : ు
# న : న
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# త : త
# ి : ి
# న : న
# ల : ల
# ే : ే
# క : క
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# ప : ప
# ా : ా
# ప : ప
# ం : ం
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# మ : మ
# ర : ర
# ్ : ్
# య : య
# ా : ా
# ద : ద
# గ : గ
# ా : ా
#   :
# న : న
# వ : వ
# ్ : ్
# వ : వ
# ి : ి
#   :
# ఆ : ఆ
# క : క
# ల : ల
# ి : ి
# త : త
# ో : ో
#   :
# ఉ : ఉ
# ం : ం
# డ : డ
# ి : ి
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# స : స
# ్ : ్
# వ : వ
# ా : ా
# ర : ర
# ్ : ్
# థ : థ
# మ : మ
# ై : ై
# న : న
#   :
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# మ : మ
# ీ : ీ
#   :
# స : స
# ూ : ూ
# ప : ప
# ్ : ్
#   :
# ఎ : ఎ
# ం : ం
# ద : ద
# ు : ు
# క : క
# ు : ు
#   :
# త : త
# ి : ి
# న : న
# ల : ల
# ే : ే
# ద : ద
# ు : ు
#   :
# మ : మ
# ీ : ీ
# క : క
# ు : ు
#   :
# న : న
# చ : చ
# ్ : ్
# చ : చ
# ల : ల
# ే : ే
# ద : ద
# ా : ా
#   :
# ” : ”
#   :
# అ : అ
# న : న
# ి : ి
#   :
# అ : అ
# డ : డ
# ి : ి
# గ : గ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# అ : అ
# ం : ం
# ద : ద
# ు : ు
# క : క
# ు : ు
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# బ : బ
# ద : ద
# ు : ు
# ల : ల
# ి : ి
# చ : చ
# ్ : ్
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
#   :
# న : న
# న : న
# ్ : ్
# న : న
# ు : ు
#   :
# వ : వ
# ి : ి
# ం : ం
# ద : ద
# ు : ు
# క : క
# ు : ు
# ఆ : ఆ
# హ : హ
# ్ : ్
# వ : వ
# ా : ా
# న : న
# ి : ి
# ం : ం
# చ : చ
# డ : డ
# ం : ం
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# స : స
# ం : ం
# త : త
# ో : ో
# ష : ష
# ం : ం
#   :
# ర : ర
# ే : ే
# ప : ప
# ు : ు
#   :
# స : స
# ా : ా
# య : య
# ం : ం
# త : త
# ్ : ్
# ర : ర
# ం : ం
#   :
# ద : ద
# య : య
# చ : చ
# ే : ే
# స : స
# ి : ి
#   :
# న : న
# ా : ా
#   :
# ఇ : ఇ
# ం : ం
# ట : ట
# ్ : ్
# ల : ల
# ో : ో
#   :
# వ : వ
# ి : ి
# ం : ం
# ద : ద
# ు : ు
#   :
# క : క
# ో : ో
# స : స
# ం : ం
#   :
# న : న
# ా : ా
# త : త
# ో : ో
#   :
# చ : చ
# ే : ే
# ర : ర
# ం : ం
# డ : డ
# ి : ి
#   :
# ” : ”
#   :
#   :
# అ : అ
# న : న
# ి : ి
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# న : న
# క : క
# ్ : ్
# క : క
# న : న
# ు : ు
#   :
# ప : ప
# ి : ి
# ల : ల
# ి : ి
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# మ : మ
# ర : ర
# ు : ు
# స : స
# ట : ట
# ి : ి
#   :
# ర : ర
# ో : ో
# జ : జ
# ు : ు
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# ఇ : ఇ
# ం : ం
# ట : ట
# ి : ి
# క : క
# ి : ి
#   :
# వ : వ
# చ : చ
# ్ : ్
# చ : చ
# ి : ి
# న : న
# ప : ప
# ్ : ్
# ప : ప
# ు : ు
# డ : డ
# ు : ు
#   :
#   :
# వ : వ
# ి : ి
# ం : ం
# ద : ద
# ు : ు
#   :
# క : క
# ో : ో
# స : స
# ం : ం
#   :
# స : స
# ూ : ూ
# ప : ప
# ్ : ్
#   :
# చ : చ
# ే : ే
# స : స
# ి : ి
# ం : ం
# ద : ద
# న : న
# ి : ి
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
# చ : చ
# ూ : ూ
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
#   :
# ఈ : ఈ
# స : స
# ా : ా
# ర : ర
# ి : ి
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# స : స
# ూ : ూ
# ప : ప
# ్ : ్
# న : న
# ు : ు
#   :
# ప : ప
# ొ : ొ
# డ : డ
# వ : వ
# ై : ై
# న : న
#   :
# జ : జ
# గ : గ
# ్ : ్
# గ : గ
# ు : ు
#   :
# ల : ల
# ల : ల
# ో : ో
# వ : వ
# డ : డ
# ్ : ్
# డ : డ
# ి : ి
# ం : ం
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ొ : ొ
# ం : ం
# గ : గ
#   :
# స : స
# ూ : ూ
# ప : ప
# ్ : ్
# ‌ : ‌
# న : న
# ు : ు
#   :
# త : త
# ే : ే
# ల : ల
# ి : ి
# క : క
# గ : గ
# ా : ా
#   :
# త : త
# ా : ా
# గ : గ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ా : ా
# న : న
# ి : ి
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
# ప : ప
# ొ : ొ
# డ : డ
# వ : వ
# ై : ై
# న : న
#   :
# క : క
# ూ : ూ
# జ : జ
# ా : ా
#   :
# ల : ల
# ో : ో
# ప : ప
# ల : ల
# ి : ి
# క : క
# ి : ి
#   :
# త : త
# ల : ల
#   :
# వ : వ
# ె : ె
# ళ : ళ
# ్ : ్
# ళ : ళ
# ల : ల
# ే : ే
# ద : ద
# ు : ు
#   :
# అ : అ
# ం : ం
# ద : ద
# ు : ు
# వ : వ
# ల : ల
# ్ : ్
# ల : ల
#   :
# స : స
# ూ : ూ
# ప : ప
# ్ : ్
#   :
# న : న
# ు : ు
#   :
# త : త
# ా : ా
# గ : గ
# ల : ల
# ే : ే
# క : క
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# అ : అ
# ప : ప
# ్ : ్
# ప : ప
# ు : ు
# డ : డ
# ు : ు
#   :
# న : న
# క : క
# ్ : ్
# క : క
#   :
# త : త
# న : న
#   :
# త : త
# ప : ప
# ్ : ్
# ప : ప
# ు : ు
#   :
# త : త
# ె : ె
# ల : ల
# ు : ు
# స : స
# ు : ు
# క : క
# ొ : ొ
# న : న
# ి : ి
#   :
# త : త
# న : న
#   :
# ఇ : ఇ
# ం : ం
# ట : ట
# ి : ి
# క : క
# ి : ి
#   :
# త : త
# ి : ి
# ర : ర
# ి : ి
# గ : గ
# ి : ి
#   :
# వ : వ
# ె : ె
# ళ : ళ
# ్ : ్
# ళ : ళ
# ి : ి
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#
#  :
#
# ఒ : ఒ
# క : క
#   :
# వ : వ
# ే : ే
# స : స
# వ : వ
# ి : ి
#   :
# క : క
# ా : ా
# ల : ల
# ం : ం
#   :
# ఒ : ఒ
# క : క
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# ద : ద
# ా : ా
# హ : హ
# ం : ం
# త : త
# ో : ో
#   :
# ఉ : ఉ
# ం : ం
# ద : ద
# ి : ి
#   :
# అ : అ
# ద : ద
# ి : ి
#   :
# న : న
# ీ : ీ
# ట : ట
# ి : ి
# న : న
# ి : ి
#   :
# వ : వ
# ె : ె
# త : త
# ు : ు
# క : క
# ు : ు
# త : త
# ూ : ూ
#   :
# వ : వ
# ె : ె
# త : త
# ు : ు
# క : క
# ు : ు
# త : త
# ూ : ూ
#   :
# ప : ప
# ొ : ొ
# ల : ల
# ా : ా
# ల : ల
# ు : ు
#   :
# చ : చ
# ె : ె
# ర : ర
# ు : ు
# వ : వ
# ు : ు
# ల : ల
# ు : ు
#   :
# అ : అ
# న : న
# ్ : ్
# న : న
# ి : ి
#   :
# త : త
# ి : ి
# ర : ర
# గ : గ
# స : స
# ా : ా
# గ : గ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ా : ా
# న : న
# ీ : ీ
# ఎ : ఎ
# ం : ం
# డ : డ
# ల : ల
# ు : ు
#   :
# బ : బ
# ా : ా
# గ : గ
# ా : ా
#   :
# ఉ : ఉ
# ం : ం
# డ : డ
# డ : డ
# ం : ం
# త : త
# ో : ో
#   :
# చ : చ
# ె : ె
# ర : ర
# ు : ు
# వ : వ
# ు : ు
# ల : ల
# ు : ు
#   :
# అ : అ
# న : న
# ్ : ్
# న : న
# ి : ి
#   :
# ఎ : ఎ
# ం : ం
# డ : డ
# ి : ి
# ప : ప
# ో : ో
# య : య
# ా : ా
# య : య
# ి : ి
#   :
# ప : ప
# ొ : ొ
# ల : ల
# ం : ం
# ల : ల
# ో : ో
#   :
# క : క
# ూ : ూ
# డ : డ
# ా : ా
#   :
# న : న
# ీ : ీ
# ర : ర
# ు : ు
#   :
# ద : ద
# ొ : ొ
# ర : ర
# క : క
# ల : ల
# ే : ే
# ద : ద
# ు : ు
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# న : న
# ీ : ీ
# ర : ర
# స : స
# ి : ి
# ం : ం
# చ : చ
# ి : ి
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# ద : ద
# ా : ా
# ద : ద
# ా : ా
# ప : ప
# ు : ు
#   :
# ఈ : ఈ
#   :
# వ : వ
# ే : ే
# స : స
# వ : వ
# ి : ి
# ల : ల
# ో : ో
#   :
# న : న
# ీ : ీ
# ర : ర
# ు : ు
#   :
# ద : ద
# ొ : ొ
# ర : ర
# క : క
# డ : డ
# ం : ం
#   :
# క : క
# ష : ష
# ్ : ్
# ట : ట
# మ : మ
# న : న
# ి : ి
#   :
# ఆ : ఆ
# శ : శ
# ల : ల
# ు : ు
#   :
# వ : వ
# ద : ద
# ు : ు
# ల : ల
# ు : ు
# క : క
# ు : ు
# ం : ం
# ద : ద
# ి : ి
# ” : ”
# ఆ : ఆ
# ల : ల
# ా : ా
#   :
# ఎ : ఎ
# గ : గ
# ు : ు
# ర : ర
# ు : ు
# క : క
# ు : ు
# ం : ం
# ట : ట
# ూ : ూ
#   :
# చ : చ
# ా : ా
# ల : ల
# ా : ా
#   :
# ద : ద
# ూ : ూ
# ర : ర
# ం : ం
#   :
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# అ : అ
# క : క
# స : స
# ్ : ్
# మ : మ
# ా : ా
# త : త
# ్ : ్
# త : త
# ు : ు
# గ : గ
# ా : ా
#   :
# ద : ద
# ా : ా
# న : న
# ి : ి
# క : క
# ి : ి
#   :
# ఒ : ఒ
# క : క
# క : క
# ు : ు
# ం : ం
# డ : డ
#   :
# క : క
# న : న
# బ : బ
# డ : డ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# అ : అ
# ద : ద
# ి : ి
#   :
# న : న
# ే : ే
# ర : ర
# ు : ు
# గ : గ
# ా : ా
#   :
# క : క
# ు : ు
# ం : ం
# డ : డ
#   :
# ద : ద
# గ : గ
# ్ : ్
# గ : గ
# ర : ర
# ి : ి
# క : క
# ి : ి
#   :
# వ : వ
# ె : ె
# ళ : ళ
# ్ : ్
# ల : ల
# ి : ి
#   :
# క : క
# ు : ు
# ం : ం
# డ : డ
# ల : ల
# ో : ో
#   :
# న : న
# ీ : ీ
# ర : ర
# ు : ు
#   :
# ఉ : ఉ
# ం : ం
# ద : ద
# ా : ా
#   :
#   :
# ల : ల
# ే : ే
# ద : ద
# ా : ా
#   :
# అ : అ
# న : న
# ి : ి
#   :
# చ : చ
# ూ : ూ
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
#   :
# క : క
# ు : ు
# ం : ం
# డ : డ
#   :
# అ : అ
# డ : డ
# ు : ు
# గ : గ
# ు : ు
#   :
# బ : బ
# ా : ా
# గ : గ
# ా : ా
# న : న
#   :
#   :
# క : క
# ొ : ొ
# ం : ం
# త : త
#   :
# న : న
# ీ : ీ
# ర : ర
# ు : ు
# ఉ : ఉ
# ం : ం
# ద : ద
# ి : ి
# ” : ”
# అ : అ
# ద : ద
# ి : ి
#   :
# చ : చ
# ూ : ూ
# స : స
# ి : ి
# న : న
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# స : స
# ం : ం
# త : త
# ో : ో
# ష : ష
# ం : ం
# త : త
# ో : ో
#   :
# న : న
# ీ : ీ
# ర : ర
# ు : ు
#   :
# త : త
# ్ : ్
# ర : ర
# ా : ా
# గ : గ
# డ : డ
# ా : ా
# న : న
# ి : ి
# క : క
# ి : ి
#   :
# ప : ప
# ్ : ్
# ర : ర
# య : య
# త : త
# ్ : ్
# న : న
# ి : ి
# ం : ం
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ా : ా
# న : న
# ీ : ీ
#   :
#   :
# క : క
# ు : ు
# ం : ం
# డ : డ
#   :
# అ : అ
# డ : డ
# ు : ు
# గ : గ
# ు : ు
#   :
# బ : బ
# ా : ా
# గ : గ
# ా : ా
# న : న
#   :
# న : న
# ీ : ీ
# ర : ర
# ు : ు
#   :
# ఉ : ఉ
# న : న
# ్ : ్
# న : న
# ం : ం
# ద : ద
# ు : ు
# న : న
# ” : ”
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# న : న
# ీ : ీ
# ట : ట
# ి : ి
# న : న
# ి : ి
# అ : అ
# ం : ం
# ద : ద
# ు : ు
# క : క
# ో : ో
# ల : ల
# ే : ే
# క : క
# ప : ప
# ో : ో
# య : య
# ి : ి
# ం : ం
# ద : ద
# ి : ి
# ” : ”
# న : న
# ీ : ీ
# ర : ర
# ు : ు
#   :
# క : క
# న : న
# ్ : ్
# ప : ప
# ి : ి
# ం : ం
# చ : చ
# గ : గ
# ా : ా
# న : న
# ే : ే
#   :
# ఎ : ఎ
# ం : ం
# త : త
# ో : ో
#   :
# స : స
# ం : ం
# త : త
# ో : ో
# ష : ష
# ప : ప
# డ : డ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ా : ా
# న : న
# ీ : ీ
#   :
# త : త
# ్ : ్
# ర : ర
# ా : ా
# గ : గ
# డ : డ
# ా : ా
# న : న
# ి : ి
# క : క
# ి : ి
#   :
# అ : అ
# ం : ం
# ద : ద
# క : క
# ప : ప
# ో : ో
# వ : వ
# డ : డ
# ం : ం
# త : త
# ో : ో
#   :
#   :
# అ : అ
# ట : ట
# ు : ు
#   :
# ఇ : ఇ
# ట : ట
# ు : ు
#   :
# చ : చ
# ూ : ూ
# స : స
# ్ : ్
# త : త
# ూ : ూ
#   :
# బ : బ
# ా : ా
# గ : గ
# ా : ా
# ఆ : ఆ
# ల : ల
# ో : ో
# చ : చ
# ి : ి
# ం : ం
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# క : క
# ా : ా
# క : క
# ి : ి
# క : క
# ి : ి
#   :
# ” : ”
#   :
# గ : గ
# ు : ు
# ల : ల
# క : క
#   :
# ర : ర
# ా : ా
# ళ : ళ
# ్ : ్
# ల : ల
# ు : ు
#   :
# క : క
# న : న
# బ : బ
# డ : డ
# ్ : ్
# డ : డ
# ా : ా
# య : య
# ి : ి
# ” : ”
#   :
# క : క
# ా : ా
# క : క
# ి : ి
# క : క
# ి : ి
#   :
# మ : మ
# ం : ం
# చ : చ
# ి : ి
#   :
# ఆ : ఆ
# ల : ల
# ో : ో
# చ : చ
# న : న
#   :
# వ : వ
# చ : చ
# ్ : ్
# చ : చ
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# వ : వ
# ె : ె
# ం : ం
# ట : ట
# న : న
# ే : ే
#   :
# ” : ”
#   :
# గ : గ
# ు : ు
# ల : ల
# క : క
#   :
# ర : ర
# ా : ా
# ళ : ళ
# ్ : ్
# ళ : ళ
# న : న
# ి : ి
#   :
# ఒ : ఒ
# క : క
# ్ : ్
# క : క
# ొ : ొ
# క : క
# ్ : ్
# క : క
# ట : ట
# ి : ి
#   :
# త : త
# ీ : ీ
# స : స
# ు : ు
# క : క
# ొ : ొ
# న : న
# ి : ి
#   :
# వ : వ
# చ : చ
# ్ : ్
# చ : చ
# ి : ి
# క : క
# ు : ు
# ం : ం
# డ : డ
# ల : ల
# ో : ో
#   :
# వ : వ
# ే : ే
# స : స
# ి : ి
# ం : ం
# ద : ద
# ి : ి
#   :
# అ : అ
# ల : ల
# ా : ా
#   :
# క : క
# ొ : ొ
# న : న
# ్ : ్
# న : న
# ి : ి
#   :
#   :
# వ : వ
# ే : ే
# స : స
# ే : ే
# స : స
# ర : ర
# ి : ి
# క : క
# ి : ి
#   :
# క : క
# ు : ు
# ం : ం
# డ : డ
#   :
# అ : అ
# డ : డ
# ు : ు
# గ : గ
# ు : ు
#   :
# బ : బ
# ా : ా
# గ : గ
# ా : ా
# న : న
#   :
#   :
# ఉ : ఉ
# న : న
# ్ : ్
# న : న
#   :
# న : న
# ీ : ీ
# ళ : ళ
# ్ : ్
# ల : ల
# ు : ు
#   :
# క : క
# ా : ా
# స : స
# ్ : ్
# త : త
#   :
# ప : ప
# ై : ై
# న : న
# క : క
# ి : ి
#   :
# వ : వ
# చ : చ
# ్ : ్
# చ : చ
# ా : ా
# య : య
# ి : ి
#   :
# క : క
# ా : ా
# క : క
# ి : ి
#   :
# స : స
# ం : ం
# త : త
# ో : ో
# ష : ష
# ం : ం
# హ : హ
#   :
# న : న
# ీ : ీ
# ట : ట
# ి : ి
# న : న
# ి : ి
#   :
# త : త
# ్ : ్
# ర : ర
# ా : ా
# గ : గ
# ి : ి
# ం : ం
# ద : ద
# ి : ి

# %% [markdown]
# # Lemmatization

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
def lemetize(text):
    word_tokens = word_tokenize(text)
    filtered_word = [lem.lemmatize(word) for word in word_tokens]
    filtered_word = " ".join(filtered_word)
    return filtered_word
lemetize(tran_te_data)
# Out:
# 'అనగనగా ఒక రహదారిలో రాము గిరి అనబడే ఇద్దరు బాటసారులు కలిసి ప్రయాణం చేస్తున్నారుదారిలో అనుకోకుండా గిరికి ఒక సంచి కనిపించింది ఆ సంచి తెరిచి చూస్తే అందులో బంగారు నాణాలు ఉన్నాయి నేను యెంత అదృష్టవంతుడిని నాకు అనుకోకుండా ఇంత బంగారం దొరికింది ” అని గిరి రాముతో అన్నాడు నేను అదృష్టవంతుదిని అనకు మనం అదృష్టవంతులము ” అని రాము బదులు చెప్పాడు అదెలా కుదురుతుంది సంచి నాకు దొరికింది కనుక బంగారమూ నాడదే అదృష్టము నాదే మనం కాదు నేను అదృష్టవంతుడిని అని గిరి కోపంగా అన్నాడురాము గొడవ పడడం ఎందుకులే అనుకుని ఊరుకున్నాడుఇంతలో వెనక నుంచి దొంగ దొంగా ” అని అరుపులు వినిపించాయి వెనక్కి తిరిగి చూస్తే కొంత మంది కోపంగా కర్రలు కట్టెలు పట్టుకుని పరిగెత్తుకుంటూ వస్తున్నారు అరెరే మన దెగ్గిర కనుక ఈ సంచి చూస్తే మనం దొరికిపోతాము వాళ్ళు మనల్ని చితక్కోట్టేస్తారు ” అని గిరి ఖంగారుపడ్డాడు మనం కాదు నువ్వు దొరికిపోతావు నిన్ను చితక్కోట్టేస్తారు ఈ సంచితో నాకేమి సంబంధం లేదన్నావు కదా ” అని కూల్ గా రాము జవాబు చెప్పాడుమనం ఇతర్లతో మన అదృష్టం పంచుకోనప్పుడు వాళ్ళు మన దురదృష్టంలో కలిసి వస్తారనుకోవడం మూర్ఖత్వమే కదా ఒక కాకి ఎప్పుడు హంసలను చూసి కుళ్ళు కునేది వాటి తెల్లటి రెక్కలని అందమైన రూపాన్ని చూసి కాకి బాధ పాడేది ఎప్పుడు నేనూ అలా వుంటే బాగుండేది ఇలా నల్లగా వున్నాను ” అనుకుంటూ వుండేదిఒక రోజు కాకికి ఒక మూర్ఖమైన ఆలోచన కలిగింది హంసల లాగానే తనూ నీళ్ళల్లో ఉంటూ వాటిలా కలుపు మొక్కలు తింటూ చెరువులో ఈత కొడుతూ వుంటే అదీ చాలా అందంగా అయిపోతున్దనుకుంది ఆ పిచ్చి కాకిమొన్నాటి నుంచి నానా ప్రయత్నాలు చేసింది గాలిలో ఎగరడం మానేసి నీళ్ళల్లో ఈత కొట్టడానికి తెగ ప్రయత్నం చేసింది కాని కాకికి ఈత రాదు కదాఅలవాటు లేని కాలుకు మొక్కలు తింటే అవి పడక తినలేక పాపం కాకి చిక్కి సల్యమయిపోయిందిఅయినా పాపం చాలా రోజులు అలాగే ప్రయత్నం చేసిందికాని అందంగా తయారవడము కాదు కదా ఉన్న బలం కూడా కోలి పోయిందిఇంక ఇది లాభం లేదని అలవాట్లు మార్చినంత మాత్రాన్న రూపం మారిపోదని తెలుసుకుని కాకి ఆ పైన హంసలను చూసి అసూయ పాడడం మానేసింది ఒక స్వార్థమైన నక్క ఒక రోజు తన మిత్రుడు ఐన కొంగ ను తన ఇంటికి రాత్రి భోజనానికి ఆహ్వానించింది ఆరోజు సాయంత్రం కొంగ నక్కఇంటికి వెళ్లి కొంగ తన పొడవైన ముక్కుతో తలుపు తట్టింది నక్క తలుపు తెరిచి దయచేసి లోపలికి వచ్చి నా ఆహారాన్ని పంచుకోండిమిత్రమా ” అంది కొంగను టేబుల్ వద్ద కూర్చోమని ఆహ్వానించింది కొంగ చాలా ఆకలితో ఉంది మరియు ఆహారం రుచికరమైన వాసనచూసింది నక్క రెండు ప్లేట్లలో సూప్ వడ్డించింది మరియు నక్క తన సూప్ మొత్తాన్ని చాలా త్వరగా తినేసిందికొంగ తన పొడవైనముక్కుకు ప్లేట్ చాలా నిస్సారంగా ఉన్నందున కొంగ తినలేకపోయింది పాపం కొంగ మర్యాదగా నవ్వి ఆకలితో ఉండిపోయింది స్వార్థమైన నక్క కొంగ మీ సూప్ ఎందుకు తినలేదు మీకు నచ్చలేదా ” అని అడిగింది అందుకు కొంగ బదులిచ్చింది నన్ను విందుకుఆహ్వానించడం చాలా సంతోషం రేపు సాయంత్రం దయచేసి నా ఇంట్లో విందు కోసం నాతో చేరండి ” అని కొంగ నక్కను పిలిచింది మరుసటి రోజు నక్క కొంగ ఇంటికి వచ్చినప్పుడు విందు కోసం సూప్ చేసిందని నక్క చూసింది ఈసారి కొంగ సూప్ను పొడవైన జగ్గు లలోవడ్డించింది కొంగ సూప్\u200cను తేలికగా తాగింది కాని నక్క పొడవైన కూజా లోపలికి తల వెళ్ళలేదు అందువల్ల సూప్ ను తాగలేకపోయింది అప్పుడు నక్క తన తప్పు తెలుసుకొని తన ఇంటికి తిరిగి వెళ్ళిపోయింది ఒక వేసవి కాలం ఒక కాకి చాలా దాహంతో ఉంది అది నీటిని వెతుకుతూ వెతుకుతూ పొలాలు చెరువులు అన్ని తిరగసాగింది కానీఎండలు బాగా ఉండడంతో చెరువులు అన్ని ఎండిపోయాయి పొలంలో కూడా నీరు దొరకలేదు కాకి చాలా నీరసించిపోయింది దాదాపు ఈ వేసవిలో నీరు దొరకడం కష్టమని ఆశలు వదులుకుంది ” ఆలా ఎగురుకుంటూ చాలా దూరం పోయింది అకస్మాత్తుగా దానికి ఒకకుండ కనబడింది అది నేరుగా కుండ దగ్గరికి వెళ్లి కుండలో నీరు ఉందా లేదా అని చూసింది కుండ అడుగు బాగాన కొంత నీరుఉంది ” అది చూసిన కాకి సంతోషంతో నీరు త్రాగడానికి ప్రయత్నించింది కానీ కుండ అడుగు బాగాన నీరు ఉన్నందున ” కాకి నీటినిఅందుకోలేకపోయింది ” నీరు కన్పించగానే ఎంతో సంతోషపడింది కానీ త్రాగడానికి అందకపోవడంతో అటు ఇటు చూస్తూ బాగాఆలోచించింది కాకికి ” గులక రాళ్లు కనబడ్డాయి ” కాకికి మంచి ఆలోచన వచ్చింది వెంటనే ” గులక రాళ్ళని ఒక్కొక్కటి తీసుకొని వచ్చికుండలో వేసింది అలా కొన్ని వేసేసరికి కుండ అడుగు బాగాన ఉన్న నీళ్లు కాస్త పైనకి వచ్చాయి కాకి సంతోషంహ నీటిని త్రాగింది'

# %%
print(len(tran_te_data))
# Out:
# 3675

# %% [markdown]
# # Removing stopwords with file

# %%
#stopwords
with open('/content/telugu_stopwords.txt') as fp:
	stopwords = fp.read()
print(stopwords)
# Out:
# చేయగలిగింది
# గురించి
# పై
# ప్రకారం
# అనుగుణంగా
# అడ్డంగా
# నిజంగా
# తర్వాత
# తర్వాత
# మళ్ళీ
# వ్యతిరేకంగా
# కాదు
# అందరూ
# అనుమతించు
# అనుమతిస్తుంది
# దాదాపు
# మాత్రమే
# వెంట
# ఇప్పటికే
# కూడా
# అయితే
# ఎప్పుడు
# వద్ద
# మధ్య
# మధ్య
# ఒక
# మరియు
# మరొక
# ఏ
# ఎవరో ఒకరు
# ఏమైనప్పటికి
# ఎవరైనా
# ఏదైనా
# ఏమైనప్పటికి
# ఎక్కడైనా
# వేరుగా
# కనిపిస్తాయి
# మెచ్చుకో
# తగిన
# ఉన్నారు
# కాదు
# చుట్టూ
# గా
# ఒక ప్రక్కన
# అడగండి
# అడగడం
# సంబంధం
# వద్ద
# అందుబాటులో
# దూరంగా

# %%
#removing Stopwords
words = word_tokenize(tran_te_data)
filtered_sentence = []
for w in words:
  if w not in stopwords:
    filtered_sentence.append(w)
final_list= filtered_sentence
print(filtered_sentence)
print(len(filtered_sentence))
# Out:
# ['అనగనగా', 'రహదారిలో', 'రాము', 'గిరి', 'అనబడే', 'ఇద్దరు', 'బాటసారులు', 'కలిసి', 'ప్రయాణం', 'చేస్తున్నారుదారిలో', 'అనుకోకుండా', 'గిరికి', 'సంచి', 'కనిపించింది', 'ఆ', 'సంచి', 'తెరిచి', 'చూస్తే', 'అందులో', 'బంగారు', 'నాణాలు', 'ఉన్నాయి', 'నేను', 'యెంత', 'అదృష్టవంతుడిని', 'నాకు', 'అనుకోకుండా', 'ఇంత', 'బంగారం', 'దొరికింది', '”', 'అని', 'గిరి', 'రాముతో', 'అన్నాడు', 'నేను', 'అదృష్టవంతుదిని', 'అనకు', 'మనం', 'అదృష్టవంతులము', '”', 'అని', 'రాము', 'బదులు', 'చెప్పాడు', 'అదెలా', 'కుదురుతుంది', 'సంచి', 'నాకు', 'దొరికింది', 'కనుక', 'బంగారమూ', 'నాడదే', 'అదృష్టము', 'నాదే', 'మనం', 'నేను', 'అదృష్టవంతుడిని', 'అని', 'గిరి', 'కోపంగా', 'అన్నాడురాము', 'గొడవ', 'పడడం', 'ఎందుకులే', 'అనుకుని', 'ఊరుకున్నాడుఇంతలో', 'వెనక', 'నుంచి', 'దొంగ', 'దొంగా', '”', 'అని', 'అరుపులు', 'వినిపించాయి', 'వెనక్కి', 'తిరిగి', 'చూస్తే', 'కొంత', 'మంది', 'కోపంగా', 'కర్రలు', 'కట్టెలు', 'పట్టుకుని', 'పరిగెత్తుకుంటూ', 'వస్తున్నారు', 'అరెరే', 'మన', 'దెగ్గిర', 'కనుక', 'ఈ', 'సంచి', 'చూస్తే', 'మనం', 'దొరికిపోతాము', 'వాళ్ళు', 'మనల్ని', 'చితక్కోట్టేస్తారు', '”', 'అని', 'గిరి', 'ఖంగారుపడ్డాడు', 'మనం', 'నువ్వు', 'దొరికిపోతావు', 'నిన్ను', 'చితక్కోట్టేస్తారు', 'ఈ', 'సంచితో', 'నాకేమి', 'లేదన్నావు', 'కదా', '”', 'అని', 'కూల్', 'రాము', 'జవాబు', 'చెప్పాడుమనం', 'ఇతర్లతో', 'మన', 'అదృష్టం', 'పంచుకోనప్పుడు', 'వాళ్ళు', 'మన', 'దురదృష్టంలో', 'కలిసి', 'వస్తారనుకోవడం', 'మూర్ఖత్వమే', 'కదా', 'కాకి', 'హంసలను', 'చూసి', 'కుళ్ళు', 'కునేది', 'వాటి', 'తెల్లటి', 'రెక్కలని', 'అందమైన', 'రూపాన్ని', 'చూసి', 'కాకి', 'బాధ', 'పాడేది', 'నేనూ', 'అలా', 'వుంటే', 'బాగుండేది', 'ఇలా', 'నల్లగా', 'వున్నాను', '”', 'అనుకుంటూ', 'వుండేదిఒక', 'రోజు', 'కాకికి', 'మూర్ఖమైన', 'ఆలోచన', 'కలిగింది', 'హంసల', 'లాగానే', 'తనూ', 'నీళ్ళల్లో', 'ఉంటూ', 'వాటిలా', 'కలుపు', 'మొక్కలు', 'తింటూ', 'చెరువులో', 'ఈత', 'కొడుతూ', 'వుంటే', 'అదీ', 'చాలా', 'అందంగా', 'అయిపోతున్దనుకుంది', 'ఆ', 'పిచ్చి', 'కాకిమొన్నాటి', 'నుంచి', 'నానా', 'ప్రయత్నాలు', 'చేసింది', 'గాలిలో', 'ఎగరడం', 'మానేసి', 'నీళ్ళల్లో', 'ఈత', 'కొట్టడానికి', 'తెగ', 'ప్రయత్నం', 'చేసింది', 'కాని', 'కాకికి', 'ఈత', 'రాదు', 'కదాఅలవాటు', 'లేని', 'కాలుకు', 'మొక్కలు', 'తింటే', 'అవి', 'పడక', 'తినలేక', 'పాపం', 'కాకి', 'చిక్కి', 'సల్యమయిపోయిందిఅయినా', 'పాపం', 'చాలా', 'రోజులు', 'అలాగే', 'ప్రయత్నం', 'చేసిందికాని', 'అందంగా', 'తయారవడము', 'కదా', 'బలం', 'కోలి', 'పోయిందిఇంక', 'ఇది', 'లాభం', 'లేదని', 'అలవాట్లు', 'మార్చినంత', 'మాత్రాన్న', 'రూపం', 'మారిపోదని', 'తెలుసుకుని', 'కాకి', 'ఆ', 'పైన', 'హంసలను', 'చూసి', 'అసూయ', 'పాడడం', 'మానేసింది', 'స్వార్థమైన', 'నక్క', 'రోజు', 'తన', 'మిత్రుడు', 'ఐన', 'కొంగ', 'తన', 'ఇంటికి', 'రాత్రి', 'భోజనానికి', 'ఆహ్వానించింది', 'ఆరోజు', 'సాయంత్రం', 'కొంగ', 'నక్కఇంటికి', 'వెళ్లి', 'కొంగ', 'తన', 'పొడవైన', 'ముక్కుతో', 'తలుపు', 'తట్టింది', 'నక్క', 'తలుపు', 'తెరిచి', 'దయచేసి', 'లోపలికి', 'వచ్చి', 'ఆహారాన్ని', 'పంచుకోండిమిత్రమా', '”', 'అంది', 'కొంగను', 'టేబుల్', 'కూర్చోమని', 'ఆహ్వానించింది', 'కొంగ', 'చాలా', 'ఆకలితో', 'ఉంది', 'ఆహారం', 'రుచికరమైన', 'వాసనచూసింది', 'నక్క', 'రెండు', 'ప్లేట్లలో', 'సూప్', 'వడ్డించింది', 'నక్క', 'తన', 'సూప్', 'మొత్తాన్ని', 'చాలా', 'త్వరగా', 'తినేసిందికొంగ', 'తన', 'పొడవైనముక్కుకు', 'ప్లేట్', 'చాలా', 'నిస్సారంగా', 'ఉన్నందున', 'కొంగ', 'తినలేకపోయింది', 'పాపం', 'కొంగ', 'మర్యాదగా', 'నవ్వి', 'ఆకలితో', 'ఉండిపోయింది', 'స్వార్థమైన', 'నక్క', 'కొంగ', 'మీ', 'సూప్', 'ఎందుకు', 'తినలేదు', 'మీకు', 'నచ్చలేదా', '”', 'అని', 'అడిగింది', 'అందుకు', 'కొంగ', 'బదులిచ్చింది', 'నన్ను', 'విందుకుఆహ్వానించడం', 'చాలా', 'సంతోషం', 'రేపు', 'సాయంత్రం', 'దయచేసి', 'ఇంట్లో', 'విందు', 'కోసం', 'నాతో', 'చేరండి', '”', 'అని', 'కొంగ', 'నక్కను', 'పిలిచింది', 'మరుసటి', 'రోజు', 'నక్క', 'కొంగ', 'ఇంటికి', 'వచ్చినప్పుడు', 'విందు', 'కోసం', 'సూప్', 'చేసిందని', 'నక్క', 'చూసింది', 'ఈసారి', 'కొంగ', 'సూప్ను', 'పొడవైన', 'జగ్గు', 'లలోవడ్డించింది', 'కొంగ', 'సూప్\u200cను', 'తేలికగా', 'తాగింది', 'కాని', 'నక్క', 'పొడవైన', 'కూజా', 'లోపలికి', 'తల', 'వెళ్ళలేదు', 'అందువల్ల', 'సూప్', 'తాగలేకపోయింది', 'అప్పుడు', 'నక్క', 'తన', 'తప్పు', 'తెలుసుకొని', 'తన', 'ఇంటికి', 'తిరిగి', 'వెళ్ళిపోయింది', 'వేసవి', 'కాలం', 'కాకి', 'చాలా', 'దాహంతో', 'ఉంది', 'అది', 'నీటిని', 'వెతుకుతూ', 'వెతుకుతూ', 'పొలాలు', 'చెరువులు', 'అన్ని', 'తిరగసాగింది', 'కానీఎండలు', 'బాగా ...
# 498

# %% [markdown]
# # NGRAMS

# %%
def CountFrequency(text):
    freq = {}
    for item in text:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
    return freq

# %%
from nltk.util import ngrams

sentence = tran_te_data
#unigram
uni = ngrams(sentence.split(), 1)
uni=list(uni)
dict_1=CountFrequency(uni)

#bigram
bi = ngrams(sentence.split(), 2)
bi=list(bi)
dict_2=CountFrequency(bi)

null1 = {}
for i in dict_1:
  t = i[0]
  null1[i[0]] = dict_1[i]

null2 = {}
for j in dict_2:
  t = j[0]
  null2[j[0]] = dict_2[j]
print("unigrams:")
print(dict_1)
print(len(dict_1))
print("\nbigrams:")
print(dict_2)
print(len(dict_2))
# Out:
# unigrams:
# {('అనగనగా',): 1, ('ఒక',): 8, ('రహదారిలో',): 1, ('రాము',): 3, ('గిరి',): 4, ('అనబడే',): 1, ('ఇద్దరు',): 1, ('బాటసారులు',): 1, ('కలిసి',): 2, ('ప్రయాణం',): 1, ('చేస్తున్నారుదారిలో',): 1, ('అనుకోకుండా',): 2, ('గిరికి',): 1, ('సంచి',): 4, ('కనిపించింది',): 1, ('ఆ',): 3, ('తెరిచి',): 2, ('చూస్తే',): 3, ('అందులో',): 1, ('బంగారు',): 1, ('నాణాలు',): 1, ('ఉన్నాయి',): 1, ('నేను',): 3, ('యెంత',): 1, ('అదృష్టవంతుడిని',): 2, ('నాకు',): 2, ('ఇంత',): 1, ('బంగారం',): 1, ('దొరికింది”',): 1, ('అని',): 9, ('రాముతో',): 1, ('అన్నాడు',): 1, ('అదృష్టవంతుదిని',): 1, ('అనకు',): 1, ('మనం',): 4, ('అదృష్టవంతులము”',): 1, ('బదులు',): 1, ('చెప్పాడు',): 1, ('అదెలా',): 1, ('కుదురుతుంది',): 1, ('దొరికింది',): 1, ('కనుక',): 2, ('బంగారమూ',): 1, ('నాడదే',): 1, ('అదృష్టము',): 1, ('నాదే',): 1, ('కాదు',): 3, ('కోపంగా',): 2, ('అన్నాడురాము',): 1, ('గొడవ',): 1, ('పడడం',): 1, ('ఎందుకులే',): 1, ('అనుకుని',): 1, ('ఊరుకున్నాడుఇంతలో',): 1, ('వెనక',): 1, ('నుంచి',): 2, ('దొంగ',): 1, ('దొంగా”',): 1, ('అరుపులు',): 1, ('వినిపించాయి',): 1, ('వెనక్కి',): 1, ('తిరిగి',): 2, ('కొంత',): 2, ('మంది',): 1, ('కర్రలు',): 1, ('కట్టెలు',): 1, ('పట్టుకుని',): 1, ('పరిగెత్తుకుంటూ',): 1, ('వస్తున్నారు',): 1, ('అరెరే',): 1, ('మన',): 3, ('దెగ్గిర',): 1, ('ఈ',): 3, ('దొరికిపోతాము',): 1, ('వాళ్ళు',): 2, ('మనల్ని',): 1, ('చితక్కోట్టేస్తారు”',): 1, ('ఖంగారుపడ్డాడు',): 1, ('నువ్వు',): 1, ('దొరికిపోతావు',): 1, ('నిన్ను',): 1, ('చితక్కోట్టేస్తారు',): 1, ('సంచితో',): 1, ('నాకేమి',): 1, ('సంబంధం',): 1, ('లేదన్నావు',): 1, ('కదా”',): 1, ('కూల్',): 1, ('గా',): 1, ('జవాబు',): 1, ('చెప్పాడుమనం',): 1, ('ఇతర్లతో',): 1, ('అదృష్టం',): 1, ('పంచుకోనప్పుడు',): 1, ('దురదృష్టంలో',): 1, ('వస్తారనుకోవడం',): 1, ('మూర్ఖత్వమే',): 1, ('కదా',): 2, ('కాకి',): 9, ('ఎప్పుడు',): 2, ('హంసలను',): 2, ('చూసి',): 3, ('కుళ్ళు',): 1, ('కునేది',): 1, ('వాటి',): 1, ('తెల్లటి',): 1, ('రెక్కలని',): 1, ('అందమైన',): 1, ('రూపాన్ని',): 1, ('బాధ',): 1, ('పాడేది',): 1, ('నేనూ',): 1, ('అలా',): 2, ('వుంటే',): 2, ('బాగుండేది',): 1, ('ఇలా',): 1, ('నల్లగా',): 1, ('వున్నాను”',): 1, ('అనుకుంటూ',): 1, ('వుండేదిఒక',): 1, ('రోజు',): 3, ('కాకికి',): 4, ('మూర్ఖమైన',): 1, ('ఆలోచన',): 2, ('కలిగింది',): 1, ('హంసల',): 1, ('లాగానే',): 1, ('తనూ',): 1, ('నీళ్ళల్లో',): 2, ('ఉంటూ',): 1, ('వాటిలా',): 1, ('కలుపు',): 1, ('మొక్కలు',): 2, ('తింటూ',): 1, ('చెరువులో',): 1, ('ఈత',): 3, ('కొడుతూ',): 1, ('అదీ',): 1, ('చాలా',): 9, ('అందంగా',): 2, ('అయిపోతున్దనుకుంది',): 1, ('పిచ్చి',): 1, ('కాకిమొన్నాటి',): 1, ('నానా',): 1, ('ప్రయత్నాలు',): 1, ('చేసింది',): 2, ('గాలిలో',): 1, ('ఎగరడం',): 1, ('మానేసి',): 1, ('కొట్టడానికి',): 1, ('తెగ',): 1, ('ప్రయత్నం',): 2, ('కాని',): 2, ('రాదు',): 1, ('కదాఅలవాటు',): 1, ('లేని',): 1, ('కాలుకు',): 1, ('తింటే',): 1, ('అవి',): 1, ('పడక',): 1, ('తినలేక',): 1, ('పాపం',): 3, ('చిక్కి',): 1, ('సల్యమయిపోయిందిఅయినా',): 1, ('రోజులు',): 1, ('అలాగే',): 1, ('చేసిందికాని',): 1, ('తయారవడము',): 1, ('ఉన్న',): 2, ('బలం',): 1, ('కూడా',): 2, ('కోలి',): 1, ('పోయిందిఇంక',): 1, ('ఇది',): 1, ('లాభం',): 1, ('లేదని',): 1, ('అలవాట్లు',): 1, ('మార్చినంత',): 1, ('మాత్రాన్న',): 1, ('రూపం',): 1, ('మారిపోదని',): 1, ('తెలుసుకుని',): 1, ('పైన',): 1, ('అసూయ',): 1, ('పాడడం',): 1, ('మానేసింది',): 1, ('స్వార్థమైన',): 2, ('నక్క',): 9, ('తన',): 7, ('మిత్రుడు',): 1, ('ఐన',): 1, ('కొంగ',): 12, ('ను',): 2, ('ఇంటికి',): 3, ('రాత్రి',): 1, ('భోజనానికి',): 1, ('ఆహ్వానించింది',): 2, ('ఆరోజు',): 1, ('సాయంత్రం',): 2, ('నక్కఇంటికి',): 1, ('వెళ్లి',): 2, ('పొడవైన',): 3, ('ముక్కుతో',): 1, ('తలుపు',): 2, ('తట్టింది',): 1, ('దయచేసి',): 2, ('లోపలికి',): 2, ('వచ్చి',): 1, ('నా',): 2, ('ఆహారాన్ని',): 1, ('పంచుకోండిమిత్రమా',): 1, ('”',): 5, ('అంది',): 1, ('కొంగను',): 1, ('టేబుల్',): 1, ('వద్ద',): 1, ('కూర్చోమని',): 1, ('ఆకలితో',): 2, ('ఉంది',): 2, ('మరియు',): 2, ('ఆహారం',): 1, ('రుచికరమైన',): 1, ('వాసనచూసింది',): 1, ('రెండు',): 1, ('ప్లేట్లలో',): 1, ('సూప్',): 5, ('వడ్డించింది',): 1, ('మొత్తాన్ని',): 1, ('త్వరగా',): 1, ('తినేసిందికొంగ',): 1, ('పొడవైనముక్కుకు',): 1, ('ప్లేట్',): 1, ('నిస్సారంగా',): 1, ('ఉన్నందున',): 1, ('తినలేకపోయింది',): 1, ('మర్యాదగా',): 1, ('నవ్వి',): 1, ('ఉండిపోయింది',): 1, ('మీ' ...
# 351
#
# bigrams:
# {('అనగనగా', 'ఒక'): 1, ('ఒక', 'రహదారిలో'): 1, ('రహదారిలో', 'రాము'): 1, ('రాము', 'గిరి'): 1, ('గిరి', 'అనబడే'): 1, ('అనబడే', 'ఇద్దరు'): 1, ('ఇద్దరు', 'బాటసారులు'): 1, ('బాటసారులు', 'కలిసి'): 1, ('కలిసి', 'ప్రయాణం'): 1, ('ప్రయాణం', 'చేస్తున్నారుదారిలో'): 1, ('చేస్తున్నారుదారిలో', 'అనుకోకుండా'): 1, ('అనుకోకుండా', 'గిరికి'): 1, ('గిరికి', 'ఒక'): 1, ('ఒక', 'సంచి'): 1, ('సంచి', 'కనిపించింది'): 1, ('కనిపించింది', 'ఆ'): 1, ('ఆ', 'సంచి'): 1, ('సంచి', 'తెరిచి'): 1, ('తెరిచి', 'చూస్తే'): 1, ('చూస్తే', 'అందులో'): 1, ('అందులో', 'బంగారు'): 1, ('బంగారు', 'నాణాలు'): 1, ('నాణాలు', 'ఉన్నాయి'): 1, ('ఉన్నాయి', 'నేను'): 1, ('నేను', 'యెంత'): 1, ('యెంత', 'అదృష్టవంతుడిని'): 1, ('అదృష్టవంతుడిని', 'నాకు'): 1, ('నాకు', 'అనుకోకుండా'): 1, ('అనుకోకుండా', 'ఇంత'): 1, ('ఇంత', 'బంగారం'): 1, ('బంగారం', 'దొరికింది”'): 1, ('దొరికింది”', 'అని'): 1, ('అని', 'గిరి'): 3, ('గిరి', 'రాముతో'): 1, ('రాముతో', 'అన్నాడు'): 1, ('అన్నాడు', 'నేను'): 1, ('నేను', 'అదృష్టవంతుదిని'): 1, ('అదృష్టవంతుదిని', 'అనకు'): 1, ('అనకు', 'మనం'): 1, ('మనం', 'అదృష్టవంతులము”'): 1, ('అదృష్టవంతులము”', 'అని'): 1, ('అని', 'రాము'): 1, ('రాము', 'బదులు'): 1, ('బదులు', 'చెప్పాడు'): 1, ('చెప్పాడు', 'అదెలా'): 1, ('అదెలా', 'కుదురుతుంది'): 1, ('కుదురుతుంది', 'సంచి'): 1, ('సంచి', 'నాకు'): 1, ('నాకు', 'దొరికింది'): 1, ('దొరికింది', 'కనుక'): 1, ('కనుక', 'బంగారమూ'): 1, ('బంగారమూ', 'నాడదే'): 1, ('నాడదే', 'అదృష్టము'): 1, ('అదృష్టము', 'నాదే'): 1, ('నాదే', 'మనం'): 1, ('మనం', 'కాదు'): 2, ('కాదు', 'నేను'): 1, ('నేను', 'అదృష్టవంతుడిని'): 1, ('అదృష్టవంతుడిని', 'అని'): 1, ('గిరి', 'కోపంగా'): 1, ('కోపంగా', 'అన్నాడురాము'): 1, ('అన్నాడురాము', 'గొడవ'): 1, ('గొడవ', 'పడడం'): 1, ('పడడం', 'ఎందుకులే'): 1, ('ఎందుకులే', 'అనుకుని'): 1, ('అనుకుని', 'ఊరుకున్నాడుఇంతలో'): 1, ('ఊరుకున్నాడుఇంతలో', 'వెనక'): 1, ('వెనక', 'నుంచి'): 1, ('నుంచి', 'దొంగ'): 1, ('దొంగ', 'దొంగా”'): 1, ('దొంగా”', 'అని'): 1, ('అని', 'అరుపులు'): 1, ('అరుపులు', 'వినిపించాయి'): 1, ('వినిపించాయి', 'వెనక్కి'): 1, ('వెనక్కి', 'తిరిగి'): 1, ('తిరిగి', 'చూస్తే'): 1, ('చూస్తే', 'కొంత'): 1, ('కొంత', 'మంది'): 1, ('మంది', 'కోపంగా'): 1, ('కోపంగా', 'కర్రలు'): 1, ('కర్రలు', 'కట్టెలు'): 1, ('కట్టెలు', 'పట్టుకుని'): 1, ('పట్టుకుని', 'పరిగెత్తుకుంటూ'): 1, ('పరిగెత్తుకుంటూ', 'వస్తున్నారు'): 1, ('వస్తున్నారు', 'అరెరే'): 1, ('అరెరే', 'మన'): 1, ('మన', 'దెగ్గిర'): 1, ('దెగ్గిర', 'కనుక'): 1, ('కనుక', 'ఈ'): 1, ('ఈ', 'సంచి'): 1, ('సంచి', 'చూస్తే'): 1, ('చూస్తే', 'మనం'): 1, ('మనం', 'దొరికిపోతాము'): 1, ('దొరికిపోతాము', 'వాళ్ళు'): 1, ('వాళ్ళు', 'మనల్ని'): 1, ('మనల్ని', 'చితక్కోట్టేస్తారు”'): 1, ('చితక్కోట్టేస్తారు”', 'అని'): 1, ('గిరి', 'ఖంగారుపడ్డాడు'): 1, ('ఖంగారుపడ్డాడు', 'మనం'): 1, ('కాదు', 'నువ్వు'): 1, ('నువ్వు', 'దొరికిపోతావు'): 1, ('దొరికిపోతావు', 'నిన్ను'): 1, ('నిన్ను', 'చితక్కోట్టేస్తారు'): 1, ('చితక్కోట్టేస్తారు', 'ఈ'): 1, ('ఈ', 'సంచితో'): 1, ('సంచితో', 'నాకేమి'): 1, ('నాకేమి', 'సంబంధం'): 1, ('సంబంధం', 'లేదన్నావు'): 1, ('లేదన్నావు', 'కదా”'): 1, ('కదా”', 'అని'): 1, ('అని', 'కూల్'): 1, ('కూల్', 'గా'): 1, ('గా', 'రాము'): 1, ('రాము', 'జవాబు'): 1, ('జవాబు', 'చెప్పాడుమనం'): 1, ('చెప్పాడుమనం', 'ఇతర్లతో'): 1, ('ఇతర్లతో', 'మన'): 1, ('మన', 'అదృష్టం'): 1, ('అదృష్టం', 'పంచుకోనప్పుడు'): 1, ('పంచుకోనప్పుడు', 'వాళ్ళు'): 1, ('వాళ్ళు', 'మన'): 1, ('మన', 'దురదృష్టంలో'): 1, ('దురదృష్టంలో', 'కలిసి'): 1, ('కలిసి', 'వస్తారనుకోవడం'): 1, ('వస్తారనుకోవడం', 'మూర్ఖత్వమే'): 1, ('మూర్ఖత్వమే', 'కదా'): 1, ('కదా', 'ఒక'): 1, ('ఒక', 'కాకి'): 2, ('కాకి', 'ఎప్పుడు'): 1, ('ఎప్పుడు', 'హంసలను'): 1, ('హంసలను', 'చూసి'): 2, ('చూసి', 'కుళ్ళు'): 1, ('కుళ్ళు', 'కునేది'): 1, ('కునేది', 'వాటి'): 1, ('వాటి', 'తెల్లటి'): 1, ('తెల్లటి', 'రెక్కలని'): 1, ('రెక్కలని', 'అందమైన'): 1, ('అందమైన', 'రూపాన్ని'): 1, ('రూపాన్ని', 'చూసి'): 1, ('చూసి', 'కాకి'): 1, ('కాకి', 'బాధ'): 1, ('బాధ', 'పాడేది'): 1, ('పాడేది', 'ఎప్పుడు'): 1, ('ఎప్పుడు', 'నేనూ'): 1, ('నేనూ', 'అలా'): 1, ('అలా', 'వుంటే'): 1, ('వుంటే', 'బాగుండేది'): 1, ('బాగుండేది', 'ఇలా'): 1, ('ఇలా', 'నల్లగా'): 1, ('నల్లగా', 'వున్నాను”'): 1, ('వున్నాను”', 'అనుకుంటూ'): 1, ('అనుకుంటూ', 'వుండేదిఒక'): 1, ('వుండేదిఒక', 'రోజు'): 1, ('రోజు', 'కాకికి'): 1, ('కాకికి', 'ఒక'): 1, ('ఒక', 'మూర్ఖమైన'): 1, (' ...
# 493

# %%
import pandas as pd
df1=pd.DataFrame(null1.items(),columns=['word','freq'])
df2=pd.DataFrame(null2.items(),columns=['word','freq'])
highdf=df1.nlargest(n=7, columns=['freq'])
highdf
# Out:
#      word  freq
# 191  కొంగ    12
# 29    అని     9
# 98   కాకి     9
# 138  చాలా     9
# 187  నక్క     9
# 1      ఒక     8
# 188    తన     7

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(highdf['word'],highdf['freq'])
plt.show()

# %% [markdown]
# # POS TAGGING

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# Raw Data

# %%
from collections import Counter
import nltk

tokenized = sent_tokenize(telugu_data)
for i in tokenized:
# Word tokenizers is used to find the words
    wordsList = nltk.word_tokenize(i)
 
# removing stop words from wordList
    wordsList = [w for w in wordsList if not w in stopwords]
 
    #  Using a Tagger we will find part-of-speech
    pos_tagged = nltk.pos_tag(wordsList)
 
    print(pos_tagged,end="\n")
# Out:
# [('అనగనగా', 'JJ'), ('రహదారిలో', 'NNP'), ('రాము', 'NNP'), (',', ','), ('గిరి', 'NNP'), ('అనబడే', 'NNP'), ('ఇద్దరు', 'NNP'), ('బాటసారులు', 'NNP'), ('కలిసి', 'NNP'), ('ప్రయాణం', 'NNP'), ('చేస్తున్నారు.దారిలో', 'NNP'), ('అనుకోకుండా', 'NNP'), ('గిరికి', 'NNP'), ('సంచి', 'NNP'), ('కనిపించింది', 'NNP'), ('.', '.')]
# [('ఆ', 'JJ'), ('సంచి', 'NNP'), ('తెరిచి', 'NNP'), ('చూస్తే', 'NNP'), ('అందులో', 'NNP'), ('బంగారు', 'NNP'), ('నాణాలు', 'NNP'), ('ఉన్నాయి', 'NN'), ('!', '.'), ('“', 'JJ'), ('నేను', 'JJ'), ('యెంత', 'NN'), ('అదృష్టవంతుడిని', 'NN'), (',', ','), ('నాకు', 'NNP'), ('అనుకోకుండా', 'NNP'), ('ఇంత', 'NNP'), ('బంగారం', 'NNP'), ('దొరికింది', 'NN'), ('!', '.'), ('”', 'JJ'), ('అని', 'JJ'), ('గిరి', 'NN'), ('రాముతో', 'NNP'), ('అన్నాడు.', 'NNP'), ('“', 'NNP'), ('నేను', 'NNP'), ('అదృష్టవంతుదిని', 'NNP'), ('అనకు', 'NNP'), (',', ','), ('మనం', 'NNP'), ('అదృష్టవంతులము', 'NNP'), ('”', 'NNP'), ('అని', 'NNP'), ('రాము', 'NNP'), ('బదులు', 'NNP'), ('చెప్పాడు.', 'NNP'), ('“', 'NNP'), ('అదెలా', 'NNP'), ('కుదురుతుంది', 'NNP'), ('?', '.')]
# [('సంచి', 'JJ'), ('నాకు', 'NNP'), ('దొరికింది', 'NNP'), ('కనుక', 'NNP'), ('బంగారమూ', 'NNP'), ('నాడదే', 'NNP'), (',', ','), ('అదృష్టము', 'NNP'), ('నాదే', 'NN'), ('!', '.')]
# [('మనం', 'NN'), (';', ':'), ('నేను', 'CC'), ('అదృష్టవంతుడిని', 'CD'), ('!', '.')]
# [('అని', 'JJ'), ('గిరి', 'NNP'), ('కోపంగా', 'NNP'), ('అన్నాడు.రాము', 'NNP'), ('గొడవ', 'NNP'), ('పడడం', 'NNP'), ('ఎందుకులే', 'NNP'), ('అనుకుని', 'NNP'), ('ఊరుకున్నాడు.ఇంతలో', 'NNP'), ('వెనక', 'NNP'), ('నుంచి', 'NNP'), ('“', 'NNP'), ('దొంగ', 'NN'), ('!', '.')]
# [('దొంగా', 'NN'), ('!', '.'), ('”', 'JJ'), ('అని', 'JJ'), ('అరుపులు', 'NN'), ('వినిపించాయి', 'NN'), ('.', '.')]
# [('వెనక్కి', 'JJ'), ('తిరిగి', 'NNP'), ('చూస్తే', 'NNP'), ('కొంత', 'NNP'), ('మంది', 'NNP'), ('కోపంగా', 'NNP'), ('కర్రలు', 'NNP'), (',', ','), ('కట్టెలు', 'NNP'), ('పట్టుకుని', 'NNP'), ('పరిగెత్తుకుంటూ', 'NNP'), ('వస్తున్నారు', 'NN'), ('!', '.'), ('“', 'JJ'), ('అరెరే', 'NN'), ('!', '.')]
# [('మన', 'JJ'), ('దెగ్గిర', 'NNP'), ('కనుక', 'NNP'), ('ఈ', 'NNP'), ('సంచి', 'NNP'), ('చూస్తే', 'NNP'), ('మనం', 'NNP'), ('దొరికిపోతాము', 'NNP'), ('.', '.')]
# [('వాళ్ళు', 'JJ'), ('మనల్ని', 'NNP'), ('చితక్కోట్టేస్తారు', 'NN'), ('!', '.'), ('”', 'JJ'), ('అని', 'JJ'), ('గిరి', 'NN'), ('ఖంగారుపడ్డాడు.', 'NNP'), ('“', 'NNP'), ('మనం', 'NNP'), (',', ','), ('నువ్వు', 'NNP'), ('దొరికిపోతావు', 'NNP'), ('.', '.')]
# [('నిన్ను', 'JJ'), ('చితక్కోట్టేస్తారు', 'NN'), ('.', '.')]
# [('ఈ', 'JJ'), ('సంచితో', 'NNP'), ('నాకేమి', 'NNP'), ('లేదన్నావు', 'NNP'), ('కదా', 'NNP'), ('”', 'NNP'), ('అని', 'NNP'), ('కూల్', 'NNP'), ('రాము', 'NNP'), ('జవాబు', 'NNP'), ('చెప్పాడు.మనం', 'NNP'), ('ఇతర్లతో', 'NNP'), ('మన', 'NNP'), ('అదృష్టం', 'NNP'), ('పంచుకోనప్పుడు', 'NNP'), ('వాళ్ళు', 'NNP'), ('మన', 'NNP'), ('దురదృష్టంలో', 'NNP'), ('కలిసి', 'NNP'), ('వస్తారనుకోవడం', 'NNP'), ('మూర్ఖత్వమే', 'NNP'), ('కదా', 'NN'), ('!', '.')]
# [('కాకి', 'JJ'), ('హంసలను', 'NNP'), ('చూసి', 'NNP'), ('కుళ్ళు', 'NNP'), ('కునేది', 'NNP'), ('.', '.')]
# [('వాటి', 'JJ'), ('తెల్లటి', 'NNP'), ('రెక్కలని', 'NNP'), (',', ','), ('అందమైన', 'NNP'), ('రూపాన్ని', 'NNP'), ('చూసి', 'NNP'), ('కాకి', 'NNP'), ('బాధ', 'NNP'), ('పాడేది', 'NNP'), ('.', '.')]
# [('“', 'JJ'), ('నేనూ', 'NNP'), ('అలా', 'NNP'), ('వుంటే', 'NNP'), ('బాగుండేది', 'NN'), ('!', '.')]
# [('ఇలా', 'JJ'), ('నల్లగా', 'NNP'), ('వున్నాను', 'NNP'), ('”', 'NNP'), ('అనుకుంటూ', 'NNP'), ('వుండేది.ఒక', 'NNP'), ('రోజు', 'NNP'), ('కాకికి', 'NNP'), ('మూర్ఖమైన', 'NNP'), ('ఆలోచన', 'NNP'), ('కలిగింది', 'NNP'), ('.', '.')]
# [('హంసల', 'JJ'), ('లాగానే', 'NNP'), ('తనూ', 'NNP'), ('నీళ్ళల్లో', 'NNP'), ('ఉంటూ', 'NNP'), (',', ','), ('వాటిలా', 'NNP'), ('కలుపు', 'NNP'), ('మొక్కలు', 'NNP'), ('తింటూ', 'NNP'), (',', ','), ('చెరువులో', 'NNP'), ('ఈత', 'NNP'), ('కొడుతూ', 'NNP'), ('వుంటే', 'NNP'), ('అదీ', 'NNP'), ('చాలా', 'NNP'), ('అందంగా', 'NNP'), ('అయిపోతున్దనుకుంది', 'NNP'), ('ఆ', 'NNP'), ('పిచ్చి', 'NNP'), ('కాకి.మొన్నాటి', 'NNP'), ('నుంచి', 'NNP'), ('నానా', 'NNP'), ('ప్రయత్నాలు', 'NNP'), ('చేసింది', 'NNP'), ('.', '.')]
# [('గాలిలో', 'JJ'), ('ఎగరడం', 'NNP'), ('మానేసి', 'NNP'), ('నీళ్ళల్లో', 'NNP'), ('ఈత', 'NNP'), ('కొట్టడానికి', 'NNP'), ('తెగ', 'NNP'), ('ప్రయత్నం', 'NNP'), ('చేసింది', 'NNP'), ('.', '.')]
# [('కాని', 'JJ'), ('కాకికి', 'NNP'), ('ఈత', 'NNP'), ('రాదు', 'NNP'), ('కదా', 'NN'), ('!', '.'), ('అలవాటు', 'JJ'), ('లేని', 'JJ'), ('కాలుకు', 'NN'), ('మొక్కలు', 'NNP'), ('తింటే', 'NNP'), ('అవి', 'NNP'), ('పడక', 'NNP'), (',', ','), ('తినలేక', 'NNP'), (',', ','), ('పాపం', 'NNP'), ('కాకి', 'NNP'), ('చిక్కి', 'NNP'), ('సల్యమయిపోయింది.అయినా', 'NNP'), ('పాపం', 'NNP'), ('చాలా', 'NNP'), ('రోజులు', 'NNP'), ('అలాగే', 'NNP'), ('ప్రయత్నం', 'NNP'), ('చేసింది.కాని', 'NNP'), ('అందంగా', 'NNP'), ('తయారవడము', 'NNP'), ('కదా', 'NNP'), (',', ','), ('బలం', 'NNP'), ('కోలి', 'NNP'), ('పోయింది.ఇంక', 'NNP'), ('ఇది', 'NNP'), ('లాభం', 'NNP'), ('లేదని', 'NNP'), (',', ','), ('అలవాట్లు', 'NNP'), ('మార్చినంత', 'NNP'), ('మాత్రాన్న', 'NNP'), ('రూపం', 'NNP'), ('మారిపోదని', 'NNP'), ('తెలుసుకుని', 'NNP'), ('కాకి', 'NNP'), ('ఆ', 'NNP'), ('పైన', 'NNP'), ('హంసలను', 'NNP'), ('చూసి', 'NNP'), ('అసూయ', 'NNP'), ('పాడడం', 'NNP'), ('మానేసింది', 'NNP'), ('.', '.')]
# [('స్వార్థమైన', 'JJ'), ('నక్క', 'NNP'), ('రోజు', 'NNP'), ('తన', 'NNP'), ('మిత్రుడు', 'NNP'), ('ఐన', 'NNP'), ('కొంగ', 'NNP'), ('తన', 'NNP'), ('ఇంటికి', 'NNP'), ('రాత్రి', 'NNP'), ('భోజనానికి', 'NNP'), ('ఆహ్వానించింది', 'NNP'), ('.', '.')]
# [('ఆరోజు', 'NN'), ('సాయంత్రం', 'NN'), (',', ','), ('కొంగ', 'NNP'), ('నక్కఇంటికి', 'NNP'), ('వెళ్లి', 'NNP'), (',', ','), ('కొంగ', 'NNP'), ('తన', 'NNP'), ('పొడవైన', 'NNP'), ('ముక్కుతో', 'NNP'), ('తలుపు', 'NNP'), ('తట్టింది', 'NNP'), ('.', '.')]
# [('నక్క', 'JJ'), ('తలుపు', 'NNP'), ('తెరిచి', 'NNP'), (',', ','), ('“', 'NNP'), ('దయచేసి', 'NNP'), ('లోపలికి', 'NNP'), ('వచ్చి', 'NNP'), ('ఆహారాన్ని', 'NNP'), ('పంచుకోండిమిత్రమా', 'NNP'), ('”', 'NNP'), ('అంది', 'NNP'), ('.', '.')]
# [('కొంగను', 'JJ'), ('టేబుల్', 'NNP'), ('కూర్చోమని', 'NNP'), ('ఆహ్వానించింది', 'NNP'), ('.', '.')]
# [('కొంగ', 'JJ'), ('చాలా', 'NNP'), ('ఆకలితో', 'NNP'), ('ఉంది', 'NNP'), ('ఆహారం', 'NNP'), ('రుచికరమైన', 'NNP'), ('వాసనచూసింది', 'NN'), ('!', '.')]
# [('నక్క', 'JJ'), ('రెండు', 'NNP'), ('ప్లేట్లలో', 'NNP'), ('సూప్', 'NNP'), ('వడ్డించింది', 'NNP'), ('నక్క', 'NNP'), ('తన', 'NNP'), ('సూప్', 'NNP'), ('మొత్తాన్ని', 'NNP'), ('చాలా', 'NNP'), ('త్వరగా', 'NNP'), ('తినేసింది.కొంగ', 'NNP'), ('తన', 'NNP'), ('పొడవైనముక్కుకు', 'NNP'), ('ప్లేట్', 'NNP'), ('చాలా', 'NNP'), ('నిస్సారంగా', 'NNP'), ('ఉన్నందున', 'NNP'), ('కొంగ', 'NNP'), ('తినలేకపోయింది', 'NNP'), ('.', '.')]
# [('పాపం', 'JJ'), ('కొంగ', 'NNP'), ('మర్యాదగా', 'NNP'), ('నవ్వి', 'NNP'), ('ఆకలితో', 'NNP'), ('ఉండిపోయింది', 'NNP'), ('.', '.')]
# [('స్వార్థమైన', 'NN'), ('నక్క', 'NN'), (',', ','), ('“', 'NNP'), ('కొంగ', 'NNP'), (',', ','), ('మీ', 'NNP'), ('సూప్', 'NNP'), ('ఎందుకు', 'NNP'), ('తినలేదు', 'NNP'), ('?', '.')]
# [('మీకు', 'NN'), ('నచ్చలేదా', 'NN'), ('?', '.')]
# [('”', 'JJ'), ('అని', 'NNP'), ('అడిగింది..', 'NNP'), ('అందుకు', 'NNP'), ('కొంగ', 'NNP'), ('బదులిచ్చింది', 'NNP'), (',', ','), ('“', 'NNP'), ('నన్ను', 'NNP'), ('విందుకుఆహ్వానించడం', 'NNP'), ('చాలా', 'NNP'), ('సంతోషం', 'NNP'), ('.', '.')]
# [('రేపు', 'NN'), ('సాయంత్రం', 'NN'), (',', ','), ('దయచేసి', 'NNP'), ('ఇంట్లో', 'NNP'), ('విందు', 'NNP'), ('కోసం', 'NNP'), ('నాతో', 'NNP'), ('చేరండి', 'NNP'), ('.', '.')]
# [('”', 'JJ'), ('అని', 'NNP'), ('కొంగ', 'NNP'), ('నక్కను', 'NNP'), ('పిలిచింది', 'NNP'), ('.', '.')]
# [('మరుసటి', 'NN'), ('రోజు', 'NN'), (',', ','), ('నక్క', 'NNP'), ('కొంగ', 'NNP'), ('ఇంటికి', 'NNP'), ('వచ్చినప్పుడు', 'NNP'), (',', ','), ('విందు', 'NNP'), ('కోసం', 'NNP'), ('సూప్', 'NNP'), ('చేసిందని', 'NNP'), ('నక్క', 'NNP'), ('చూసింది', 'NNP'), ('.', '.')]
# [('ఈసారి', 'JJ'), ('కొంగ', 'NNP'), ('సూప్ను', 'NNP'), ('పొడవైన', 'NNP'), ('జగ్గు', 'NNP'), ('లలోవడ్డించింది', 'NNP'), ('.', '.')]
# [('కొంగ', 'JJ'), ('సూప్\u200cను', 'NNP'), ('తేలికగా', 'NNP'), ('తాగింది', 'NNP'), (',', ','), ('కాని', 'NNP'), ('నక్క', 'NNP'), ('పొడవైన', 'NNP'), ('కూజా', 'NNP'), ('లోపలికి', 'NNP'), ('తల', 'NNP'), ('వెళ్ళలేదు', 'NNP'), ('అందువల్ల', 'NNP'), ('సూప్', 'NNP'), ('తాగలేకపోయింది', 'NNP'), ('.', '.')]
# [('అప్పుడు', 'JJ'), ('నక్క', 'NNP'), ('తన', 'NNP'), ('తప్పు', 'NNP'), ('తెలుసుకొని', 'NNP'), ('తన', 'NNP'), ('ఇంటికి', 'NNP'), ('తిరిగి', 'NNP'), ('వెళ్ళిపోయింది', 'NNP'), ('.', '.')]
# [('వేసవి', 'JJ'), ('కాలం', 'NNP'), ('కాకి', 'NNP'), ('చాలా', 'NNP'), ('దాహంతో', 'NNP'), ('ఉంది', 'NNP'), ('.', '.')]
# [('అది', 'JJ'), ('నీటిని', 'NNP'), ('వెతుకుతూ', 'NNP'), ('వెతుకుతూ', 'NNP'), ('పొలాలు', 'NNP'), ('చెరువులు', 'NNP'), ('అన్ని', 'NNP'), ('తిరగసాగింది', 'NNP'), ('.', '.')]
# [('కానీఎండలు', 'JJ'), ('బాగా', 'NNP'), ('ఉండడంతో', 'NNP'), ('చెరువులు', 'NNP'), ('అన్ని', 'NNP'), ('ఎండిపోయాయి', 'NNP'), (',', ','), ('పొలంలో', 'NNP'), ('నీరు', 'NNP'), ('దొరకలేదు', 'NNP'), ('.', '.')]
# [('కాకి', 'JJ'), ('చాలా', 'NNP'), ('నీరసించిపోయింది', 'NNP'), (',', ','), ('“', 'NNP'), ('ఈ', 'NNP'), ('వేసవిలో', 'NNP'), ('నీరు', 'NNP'), ('దొరకడం', 'NNP'), ('కష్టమని', 'NNP'), ('ఆశలు', 'NNP'), ('వదులుకుంది', 'NNP'), ('”', 'NNP'), ('ఆలా', 'NNP'), ('ఎగురుకుంటూ', 'NNP'), ('చాలా', 'NNP'), ('పోయింది', 'NNP'), ('.', '.')]
# [('అకస్మాత్తుగా', 'JJ'), ('దానికి', 'NNP'), ('ఒకకుండ', 'NNP'), ('కనబడింది', 'NNP'), ('.', '.')]
# [('అది', 'JJ'), ('నేరుగా', 'NNP'), ('కుండ', 'NNP'), ('దగ్గరికి', 'NNP'), ('వెళ్లి', 'NNP'), ('కుండలో', 'NNP'), ('నీరు', 'NNP'), ('ఉందా', 'NNP'), ('?', '.')]
# [('లేదా', 'NN'), ('!', '.')]
# [('అని', 'JJ'), ('చూసింది', 'NN'), ('.', '.')]
# [('“', 'JJ'), ('కుండ', 'NNP'), ('అడుగు', 'NNP'), ('బాగాన', 'NNP'), ('కొంత', 'NNP'), ('నీరుఉంది', 'NNP'), ('”', 'NNP'), ('.అది', 'NNP'), ('చూసిన', 'NNP'), ('కాకి', 'NNP'), ('సంతోషంతో', 'NNP'), ('నీరు', 'NNP'), ('త్రాగడానికి', 'NNP'), ('ప్రయత్నించింది', 'NNP'), ('.', '.')]
# [('కానీ', 'JJ'), ('“', 'NNP'), ('కుండ', 'NNP'), ('అడుగు', 'NNP'), ('బాగాన', 'NNP'), ('నీరు', 'NNP'), ('ఉన్నందున', 'NNP'), ('”', 'NNP'), ('కాకి', 'NNP'), ('నీటినిఅందుకోలేకపోయింది', 'NNP'), ('”', 'NNP'), ('.నీరు', 'NNP'), ('కన్పించగానే', 'NNP'), ('ఎంతో', 'NNP'), ('సంతోషపడింది', 'NNP'), ('.', '.')]
# [('కానీ', 'JJ'), ('త్రాగడానికి', 'NNP'), ('అందకపోవడంతో', 'NNP'), ('“', 'NNP'), ('అటు', 'NNP'), ('ఇటు', 'NNP'), ('చూస్తూ', 'NNP'), ('బాగాఆలోచించింది', 'NNP'), ('.', '.')]
# [('కాకికి', 'JJ'), ('”', 'NNP'), ('గులక', 'NNP'), ('రాళ్లు', 'NNP'), ('కనబడ్డాయి', 'NNP'), ('”', 'NNP'), ('.', '.')]
# [('కాకికి', 'JJ'), ('మంచి', 'NNP'), ('ఆలోచన', 'NNP'), ('వచ్చింది', 'NNP'), ('వెంటనే', 'NNP'), ('”', 'NNP'), ('గులక', 'NNP'), ('రాళ్ళని', 'NNP'), ('ఒక్కొక్కటి', 'NNP'), ('తీసుకొని', 'NNP'), ('వచ్చికుండలో', 'NNP'), ('వేసింది', 'NNP'), ('అలా', 'NNP'), ('కొన్ని', 'NNP'), ('వేసేసరికి', 'NNP'), ('కుండ', 'NNP'), ('అడుగు', 'NNP'), ('బాగాన', 'NNP'), ('నీళ్లు', 'NNP'), ('కాస్త', 'NNP'), ('పైనకి', 'NNP'), ('వచ్చాయి', 'NNP'), ('.', '.')]
# [('కాకి', 'JJ'), ('సంతోషంహ', 'NNP'), ('నీటిని', 'NNP'), ('త్రాగింది', 'NN')]

# %%
d=dict()
a=[]
b=[]
for i,j in pos_tagged:
  if j not in d:
    d[j]=1
  else:
    d[j]+=1

# %%
for i in d:
  a.append(i)
  b.append(d[i])

# %%
plt.figure(1,figsize=(10,3))
plt.bar(a,b, color ='blue',
        width = 0.2)
plt.xlabel("Words count in dataframe")
plt.ylabel("Count")
plt.title("count of JJ,NNP,NN")
plt.savefig("count.png")
plt.show()

# %% [markdown]
# Filtered data

# %%
from collections import Counter
import nltk

tokenized = sent_tokenize(tran_te_data)
for i in tokenized:
    wordsList = nltk.word_tokenize(i)
    wordsList = final_list
    pos_tagged_final = nltk.pos_tag(wordsList)
 
print(pos_tagged_final)
print(len(pos_tagged_final))
# Out:
# [('అనగనగా', 'JJ'), ('రహదారిలో', 'NNP'), ('రాము', 'NNP'), ('గిరి', 'NNP'), ('అనబడే', 'NNP'), ('ఇద్దరు', 'NNP'), ('బాటసారులు', 'NNP'), ('కలిసి', 'NNP'), ('ప్రయాణం', 'NNP'), ('చేస్తున్నారుదారిలో', 'NNP'), ('అనుకోకుండా', 'NNP'), ('గిరికి', 'NNP'), ('సంచి', 'NNP'), ('కనిపించింది', 'NNP'), ('ఆ', 'NNP'), ('సంచి', 'NNP'), ('తెరిచి', 'NNP'), ('చూస్తే', 'NNP'), ('అందులో', 'NNP'), ('బంగారు', 'NNP'), ('నాణాలు', 'NNP'), ('ఉన్నాయి', 'NNP'), ('నేను', 'NNP'), ('యెంత', 'NNP'), ('అదృష్టవంతుడిని', 'NNP'), ('నాకు', 'NNP'), ('అనుకోకుండా', 'NNP'), ('ఇంత', 'NNP'), ('బంగారం', 'NNP'), ('దొరికింది', 'NNP'), ('”', 'NNP'), ('అని', 'NNP'), ('గిరి', 'NNP'), ('రాముతో', 'NNP'), ('అన్నాడు', 'NNP'), ('నేను', 'NNP'), ('అదృష్టవంతుదిని', 'NNP'), ('అనకు', 'NNP'), ('మనం', 'NNP'), ('అదృష్టవంతులము', 'NNP'), ('”', 'NNP'), ('అని', 'NNP'), ('రాము', 'NNP'), ('బదులు', 'NNP'), ('చెప్పాడు', 'NNP'), ('అదెలా', 'NNP'), ('కుదురుతుంది', 'NNP'), ('సంచి', 'NNP'), ('నాకు', 'NNP'), ('దొరికింది', 'NNP'), ('కనుక', 'NNP'), ('బంగారమూ', 'NNP'), ('నాడదే', 'NNP'), ('అదృష్టము', 'NNP'), ('నాదే', 'NNP'), ('మనం', 'NNP'), ('నేను', 'NNP'), ('అదృష్టవంతుడిని', 'NNP'), ('అని', 'NNP'), ('గిరి', 'NNP'), ('కోపంగా', 'NNP'), ('అన్నాడురాము', 'NNP'), ('గొడవ', 'NNP'), ('పడడం', 'NNP'), ('ఎందుకులే', 'NNP'), ('అనుకుని', 'NNP'), ('ఊరుకున్నాడుఇంతలో', 'NNP'), ('వెనక', 'NNP'), ('నుంచి', 'NNP'), ('దొంగ', 'NNP'), ('దొంగా', 'NNP'), ('”', 'NNP'), ('అని', 'NNP'), ('అరుపులు', 'NNP'), ('వినిపించాయి', 'NNP'), ('వెనక్కి', 'NNP'), ('తిరిగి', 'NNP'), ('చూస్తే', 'NNP'), ('కొంత', 'NNP'), ('మంది', 'NNP'), ('కోపంగా', 'NNP'), ('కర్రలు', 'NNP'), ('కట్టెలు', 'NNP'), ('పట్టుకుని', 'NNP'), ('పరిగెత్తుకుంటూ', 'NNP'), ('వస్తున్నారు', 'NNP'), ('అరెరే', 'NNP'), ('మన', 'NNP'), ('దెగ్గిర', 'NNP'), ('కనుక', 'NNP'), ('ఈ', 'NNP'), ('సంచి', 'NNP'), ('చూస్తే', 'NNP'), ('మనం', 'NNP'), ('దొరికిపోతాము', 'NNP'), ('వాళ్ళు', 'NNP'), ('మనల్ని', 'NNP'), ('చితక్కోట్టేస్తారు', 'NNP'), ('”', 'NNP'), ('అని', 'NNP'), ('గిరి', 'NNP'), ('ఖంగారుపడ్డాడు', 'NNP'), ('మనం', 'NNP'), ('నువ్వు', 'NNP'), ('దొరికిపోతావు', 'NNP'), ('నిన్ను', 'NNP'), ('చితక్కోట్టేస్తారు', 'NNP'), ('ఈ', 'NNP'), ('సంచితో', 'NNP'), ('నాకేమి', 'NNP'), ('లేదన్నావు', 'NNP'), ('కదా', 'NNP'), ('”', 'NNP'), ('అని', 'NNP'), ('కూల్', 'NNP'), ('రాము', 'NNP'), ('జవాబు', 'NNP'), ('చెప్పాడుమనం', 'NNP'), ('ఇతర్లతో', 'NNP'), ('మన', 'NNP'), ('అదృష్టం', 'NNP'), ('పంచుకోనప్పుడు', 'NNP'), ('వాళ్ళు', 'NNP'), ('మన', 'NNP'), ('దురదృష్టంలో', 'NNP'), ('కలిసి', 'NNP'), ('వస్తారనుకోవడం', 'NNP'), ('మూర్ఖత్వమే', 'NNP'), ('కదా', 'NNP'), ('కాకి', 'NNP'), ('హంసలను', 'NNP'), ('చూసి', 'NNP'), ('కుళ్ళు', 'NNP'), ('కునేది', 'NNP'), ('వాటి', 'NNP'), ('తెల్లటి', 'NNP'), ('రెక్కలని', 'NNP'), ('అందమైన', 'NNP'), ('రూపాన్ని', 'NNP'), ('చూసి', 'NNP'), ('కాకి', 'NNP'), ('బాధ', 'NNP'), ('పాడేది', 'NNP'), ('నేనూ', 'NNP'), ('అలా', 'NNP'), ('వుంటే', 'NNP'), ('బాగుండేది', 'NNP'), ('ఇలా', 'NNP'), ('నల్లగా', 'NNP'), ('వున్నాను', 'NNP'), ('”', 'NNP'), ('అనుకుంటూ', 'NNP'), ('వుండేదిఒక', 'NNP'), ('రోజు', 'NNP'), ('కాకికి', 'NNP'), ('మూర్ఖమైన', 'NNP'), ('ఆలోచన', 'NNP'), ('కలిగింది', 'NNP'), ('హంసల', 'NNP'), ('లాగానే', 'NNP'), ('తనూ', 'NNP'), ('నీళ్ళల్లో', 'NNP'), ('ఉంటూ', 'NNP'), ('వాటిలా', 'NNP'), ('కలుపు', 'NNP'), ('మొక్కలు', 'NNP'), ('తింటూ', 'NNP'), ('చెరువులో', 'NNP'), ('ఈత', 'NNP'), ('కొడుతూ', 'NNP'), ('వుంటే', 'NNP'), ('అదీ', 'NNP'), ('చాలా', 'NNP'), ('అందంగా', 'NNP'), ('అయిపోతున్దనుకుంది', 'NNP'), ('ఆ', 'NNP'), ('పిచ్చి', 'NNP'), ('కాకిమొన్నాటి', 'NNP'), ('నుంచి', 'NNP'), ('నానా', 'NNP'), ('ప్రయత్నాలు', 'NNP'), ('చేసింది', 'NNP'), ('గాలిలో', 'NNP'), ('ఎగరడం', 'NNP'), ('మానేసి', 'NNP'), ('నీళ్ళల్లో', 'NNP'), ('ఈత', 'NNP'), ('కొట్టడానికి', 'NNP'), ('తెగ', 'NNP'), ('ప్రయత్నం', 'NNP'), ('చేసింది', 'NNP'), ('కాని', 'NNP'), ('కాకికి', 'NNP'), ('ఈత', 'NNP'), ('రాదు', 'NNP'), ('కదాఅలవాటు', 'NNP'), ('లేని', 'NNP'), ('కాలుకు', 'NNP'), ('మొక్కలు', 'NNP'), ('తింటే', 'NNP'), ('అవి', 'NNP'), ('పడక', 'NNP'), ('తినలేక', 'NNP'), ('పాపం', 'NNP'), ('కాకి', 'NNP'), ('చిక్కి', 'NNP'), ('సల్యమయిపోయిందిఅయినా', 'NNP'), ('పాపం', 'NNP'), ('చాలా', 'NNP'), ('రో ...
# 498

# %%
d1=dict()
a1=[]
b1=[]
for i,j in pos_tagged_final:
  if j not in d1:
    d1[j]=1
  else:
    d1[j]+=1

# %%
for i in d1:
  a1.append(i)
  b1.append(d1[i])

# %%
plt.figure(1,figsize=(10,3))
plt.bar(a1,b1, color ='blue',
        width = 0.2)
plt.xlabel("Words count in dataframe")
plt.ylabel("Count")
plt.title("count of JJ,NNP,NN")
plt.show()
